# %% [markdown]
# # Hockey Prediction System - Main Backtesting Analysis (ENHANCED)
#
# **Core overview with enhanced infrastructure and per-component logging**
#
# ---
#
# ## Overview
#
# This notebook provides comprehensive overview of backtesting results:
# - Enhanced Infrastructure - Centralized paths + component logging
# - Strategy Performance - ROI analysis and top strategies
# - Parameter Insights - Key parameter optimization findings
# - Performance Summary - Time-series overview
# - Executive Summary - Actionable recommendations
#
# **Location:** `notebooks/analysis/main_analysis.ipynb`
# **Component:** `analysis` → `logs/analysis.log`
#
# ---

# %% [markdown]
# ## Enhanced Setup & Configuration

# %%
# === ENHANCED SETUP ===
from src.utils.notebook_helper import notebook_setup_complete

env = notebook_setup_complete(
    component='analysis',
    sample_data='games',
    import_libraries=True
)

PATHS = env['PATHS']
logger = env['logger']
pd = env['pd']
np = env['np']
plt = env['plt']
perf = env['performance_tracker']

# Additional imports
import json
from datetime import datetime

try:
    import plotly.express as px
    import plotly.graph_objects as go
    from plotly.subplots import make_subplots
    import plotly.io as pio
    PLOTLY_AVAILABLE = True
except ImportError:
    PLOTLY_AVAILABLE = False
    logger.warning("Plotly not available - interactive charts will be skipped")

# Directories
RESULTS_DIR = PATHS.experiments
CHARTS_EXPORT_DIR = PATHS.model_charts

logger.info("Hockey Prediction System - Main Analysis Started")
logger.info(f"Results directory: {RESULTS_DIR}")
print(f"Enhanced notebook ready! Component: {env['component']}")

# %% [markdown]
# ## Enhanced Data Discovery & Loading

# %%
# === Data discovery with PATHS integration ===

from src.utils.file_handlers import read_json, read_csv

logger.info("Starting data discovery and loading...")
perf.start_timer('data_discovery')


def discover_result_files():
    """Discover and categorize all available result files using PATHS"""
    files = {
        'optimization_results': [],
        'optimization_detailed': [],
        'backtest_single': [],
        'backtest_bets': [],
        'performance_analysis': []
    }

    patterns = {
        'optimization_results': 'optimization_*_results_*.json',
        'optimization_detailed': 'optimization_*_detailed_*.csv',
        'backtest_single': 'backtest_results_*.json',
        'backtest_bets': 'backtest_bets_*.csv',
        'performance_analysis': 'performance_analysis_*.json'
    }

    for file_type, pattern in patterns.items():
        found_files = list(RESULTS_DIR.glob(pattern))
        files[file_type] = sorted(found_files, key=lambda x: x.stat().st_mtime, reverse=True)
        logger.debug(f"Found {len(found_files)} {file_type} files")

    return files


available_files = discover_result_files()

logger.info("Available result files discovered:")
for file_type, file_list in available_files.items():
    logger.info(f"  {file_type}: {len(file_list)} files")

perf.end_timer('data_discovery')
print("Data discovery completed")

# %%
# Data loading with intelligent source selection
logger.info("Loading primary datasets...")
perf.start_timer('data_loading')


def load_optimization_data():
    """Load optimization data from best available source"""
    # Try CSV detailed first (fastest and most complete)
    if available_files['optimization_detailed']:
        csv_path = available_files['optimization_detailed'][0]
        logger.info(f"Loading CSV optimization data: {csv_path.name}")
        try:
            df = read_csv(csv_path)
            for col in ['date', 'timestamp', 'created_at']:
                if col in df.columns:
                    df[col] = pd.to_datetime(df[col], errors='coerce')
            logger.info(f"Loaded {len(df)} strategies from CSV")
            return df, "CSV"
        except Exception as e:
            logger.error(f"Error loading {csv_path.name}: {e}")

    # Fallback to JSON
    if available_files['optimization_results']:
        json_path = available_files['optimization_results'][0]
        logger.info(f"Loading JSON optimization data: {json_path.name}")
        try:
            data = read_json(json_path)
            if data and data.get('optimization_results'):
                df = pd.DataFrame(data['optimization_results'])
                logger.info(f"Loaded {len(df)} strategies from JSON")
                return df, "JSON"
        except Exception as e:
            logger.error(f"Error loading {json_path.name}: {e}")

    logger.warning("No optimization data available")
    return None, None


def load_backtest_data():
    """Load backtest data from best available source"""
    # Try CSV bets first
    if available_files['backtest_bets']:
        csv_path = available_files['backtest_bets'][0]
        logger.info(f"Loading CSV bet data: {csv_path.name}")
        try:
            df = read_csv(csv_path)
            for col in ['date', 'timestamp', 'created_at']:
                if col in df.columns:
                    df[col] = pd.to_datetime(df[col], errors='coerce')
            logger.info(f"Loaded {len(df)} bet records from CSV")
            return df, "CSV"
        except Exception as e:
            logger.error(f"Error loading {csv_path.name}: {e}")

    # Fallback to JSON
    if available_files['backtest_single']:
        json_path = available_files['backtest_single'][0]
        logger.info(f"Loading JSON backtest data: {json_path.name}")
        try:
            data = read_json(json_path)
            if data and data.get('bet_history'):
                df = pd.DataFrame(data['bet_history'])
                df['date'] = pd.to_datetime(df['date'])
                logger.info(f"Loaded {len(df)} bet records from JSON")
                return df, "JSON"
        except Exception as e:
            logger.error(f"Error loading {json_path.name}: {e}")

    logger.warning("No backtest data available")
    return None, None


# Load primary datasets
opt_df, opt_source = load_optimization_data()
bets_df, bets_source = load_backtest_data()

logger.info("Data Loading Summary:")
logger.info(f"  Optimization: {opt_source or 'N/A'} ({len(opt_df):,} strategies)" if opt_df is not None else "  Optimization: N/A")
logger.info(f"  Backtest: {bets_source or 'N/A'} ({len(bets_df):,} records)" if bets_df is not None else "  Backtest: N/A")

perf.end_timer('data_loading')
print("Data loading completed")

# %% [markdown]
# ## Strategy Performance Overview

# %%
# Enhanced strategy performance analysis with component logging
if opt_df is not None:
    logger.info("Starting strategy performance analysis...")
    perf.start_timer('strategy_analysis')
    
    print(f"Strategy Performance Analysis ({len(opt_df)} strategies)")
    print("=" * 60)
    
    # Flexible ROI column detection
    roi_col = None
    possible_roi_cols = ['roi', 'total_return', 'return_pct', 'final_roi', 'return']
    for col in possible_roi_cols:
        if col in opt_df.columns:
            roi_col = col
            break
    
    if roi_col is None:
        logger.warning("ROI column not found")
        logger.debug(f"Available columns: {list(opt_df.columns)[:10]}...")
        print("⚠️ ROI column not found. Cannot perform analysis.")
    else:
        # Standardize and clean ROI data
        if roi_col != 'roi':
            opt_df['roi'] = opt_df[roi_col]
            logger.info(f"Using '{roi_col}' as ROI column")
        
        opt_df['roi'] = pd.to_numeric(opt_df['roi'], errors='coerce')
        opt_df = opt_df.dropna(subset=['roi'])
        
        if len(opt_df) == 0:
            logger.error("No valid ROI data after cleaning")
            print("❌ No valid ROI data after cleaning")
        else:
            # Key statistics with enhanced logging
            roi_stats = opt_df['roi'].describe()
            
            logger.info(f"ROI Statistics ({len(opt_df)} valid strategies):")
            logger.info(f"  Mean ROI: {roi_stats['mean']:.2%}")
            logger.info(f"  Median ROI: {roi_stats['50%']:.2%}")
            logger.info(f"  Best ROI: {roi_stats['max']:.2%}")
            logger.info(f"  Worst ROI: {roi_stats['min']:.2%}")
            
            print(f"\nROI Statistics ({len(opt_df)} valid strategies):")
            print(f"   Mean ROI: {roi_stats['mean']:.2%}")
            print(f"   Median ROI: {roi_stats['50%']:.2%}")
            print(f"   Best ROI: {roi_stats['max']:.2%}")
            print(f"   Worst ROI: {roi_stats['min']:.2%}")
            print(f"   Std Dev: {roi_stats['std']:.2%}")
            
            # Profitability analysis
            profitable = opt_df[opt_df['roi'] > 0]
            profitable_pct = len(profitable) / len(opt_df)
            
            logger.info(f"Profitable strategies: {len(profitable)}/{len(opt_df)} ({profitable_pct:.1%})")
            
            print(f"\nProfitability Analysis:")
            print(f"   Profitable strategies: {len(profitable)}/{len(opt_df)} ({profitable_pct:.1%})")
            if len(profitable) > 0:
                print(f"   Average profit (profitable only): {profitable['roi'].mean():.2%}")
                print(f"   Best profitable ROI: {profitable['roi'].max():.2%}")
            
            # Sharpe ratio analysis (if available)
            sharpe_cols = ['sharpe_ratio', 'sharpe', 'risk_adjusted_return']
            sharpe_col = None
            
            for col in sharpe_cols:
                if col in opt_df.columns:
                    sharpe_col = col
                    break
            
            if sharpe_col:
                if sharpe_col != 'sharpe_ratio':
                    opt_df['sharpe_ratio'] = opt_df[sharpe_col]
                
                sharpe_data = opt_df[opt_df['sharpe_ratio'].notna()]
                if len(sharpe_data) > 0:
                    sharpe_stats = sharpe_data['sharpe_ratio'].describe()
                    logger.info(f"Risk-adjusted performance: Mean Sharpe {sharpe_stats['mean']:.2f}")
                    
                    print(f"\nRisk-Adjusted Performance ({len(sharpe_data)} strategies):")
                    print(f"   Mean Sharpe Ratio: {sharpe_stats['mean']:.2f}")
                    print(f"   Best Sharpe Ratio: {sharpe_stats['max']:.2f}")
                    
                    good_sharpe = sharpe_data[sharpe_data['sharpe_ratio'] > 1.0]
                    print(f"   Strategies with Sharpe > 1.0: {len(good_sharpe)}/{len(sharpe_data)} ({len(good_sharpe)/len(sharpe_data):.1%})")

    perf.end_timer('strategy_analysis')
else:
    logger.warning("No optimization data available for strategy analysis")
    print("❌ No optimization data available for strategy analysis")

# %%
# Enhanced visualizations with automatic export paths
if opt_df is not None and 'roi' in opt_df.columns:
    logger.info("Creating enhanced performance visualizations...")
    perf.start_timer('visualization_creation')
    
    # 1. ROI Distribution
    try:
        fig_roi = px.histogram(
            opt_df, 
            x='roi',
            nbins=50,
            title="ROI Distribution - All Tested Strategies",
            labels={'roi': 'Return on Investment', 'count': 'Number of Strategies'}
        )
        
        fig_roi.add_vline(x=0, line_dash="dash", line_color="red", 
                         annotation_text="Break-even")
        fig_roi.update_xaxes(tickformat=".1%")
        fig_roi.update_layout(height=500)
        
        fig_roi.show()
        
        # Enhanced: Use PATHS for automatic chart export
        chart_path = PATHS.get_chart_file("roi_distribution", "html")
        fig_roi.write_html(chart_path)
        logger.info(f"Chart exported: {chart_path}")
        print(f"Chart saved: {chart_path.name}")
        
    except Exception as e:
        logger.error(f"Error creating ROI distribution: {e}")
    
    # 2. Top 10 Strategies Table
    try:
        logger.info("Creating top strategies analysis...")
        
        display_cols = ['roi']
        for col in ['sharpe_ratio', 'total_bets', 'win_rate', 'edge_threshold', 'min_odds']:
            if col in opt_df.columns:
                display_cols.append(col)
        
        top_strategies = opt_df.nlargest(10, 'roi')[display_cols].round(4)
        
        print("\nTop 10 Strategies by ROI:")
        
        # Format for display
        display_df = top_strategies.copy()
        for col in ['roi', 'win_rate']:
            if col in display_df.columns:
                display_df[col] = display_df[col].apply(lambda x: f"{x:.2%}" if pd.notna(x) else "N/A")
        
        print(display_df.to_string(index=False))
        
        # Log top strategies
        logger.info(f"Top strategy ROI: {opt_df['roi'].max():.2%}")
        
    except Exception as e:
        logger.error(f"Error creating top strategies table: {e}")
    
    # 3. ROI vs Sharpe (if available)
    if 'sharpe_ratio' in opt_df.columns:
        try:
            sharpe_clean = opt_df[
                (opt_df['sharpe_ratio'].notna()) & 
                (opt_df['sharpe_ratio'].between(-5, 10)) & 
                (opt_df['roi'].between(-1, 1))
            ]
            
            if len(sharpe_clean) > 0:
                fig_scatter = px.scatter(
                    sharpe_clean,
                    x='roi',
                    y='sharpe_ratio',
                    title="Risk vs Return: ROI vs Sharpe Ratio",
                    labels={'roi': 'Return on Investment', 'sharpe_ratio': 'Sharpe Ratio'}
                )
                
                fig_scatter.add_hline(y=1, line_dash="dash", line_color="green", 
                                     annotation_text="Sharpe = 1.0")
                fig_scatter.add_vline(x=0, line_dash="dash", line_color="red", 
                                     annotation_text="Break-even")
                
                fig_scatter.update_xaxes(tickformat=".1%")
                fig_scatter.update_layout(height=500)
                
                fig_scatter.show()
                
                # Enhanced: Automatic export path
                chart_path = PATHS.get_chart_file("roi_vs_sharpe", "html")
                fig_scatter.write_html(chart_path)
                logger.info(f"Chart exported: {chart_path}")
                print(f"Chart saved: {chart_path.name}")
                
        except Exception as e:
            logger.error(f"Error creating ROI vs Sharpe chart: {e}")
    
    perf.end_timer('visualization_creation')
    
else:
    logger.warning("Cannot create visualizations - no valid optimization data")
    print("❌ Cannot create visualizations - no valid optimization data")

# %% [markdown]
# ## Parameter Insights

# %%
# Enhanced parameter analysis with component logging
if opt_df is not None and 'roi' in opt_df.columns:
    logger.info("Starting parameter insights analysis...")
    perf.start_timer('parameter_analysis')
    
    print("Parameter Analysis Summary")
    print("=" * 50)
    
    # Detect available parameters
    param_mappings = {
        'edge_threshold': ['edge_threshold', 'edge_thresh', 'threshold'],
        'min_odds': ['min_odds', 'minimum_odds', 'odds_min'],
        'stake_method': ['stake_method', 'staking_method', 'stake_type'],
        'ev_method': ['ev_method', 'ev_calculation', 'expected_value_method']
    }
    
    found_params = {}
    for param_name, possible_names in param_mappings.items():
        for col_name in possible_names:
            if col_name in opt_df.columns:
                found_params[param_name] = col_name
                break
    
    if found_params:
        logger.info(f"Available Parameters: {', '.join(found_params.keys())}")
        print(f"\nAvailable Parameters: {', '.join(found_params.keys())}")
        
        # Parameter ranges and profitable insights
        profitable_strategies = opt_df[opt_df['roi'] > 0]
        
        if len(profitable_strategies) > 0:
            logger.info(f"Analyzing {len(profitable_strategies)} profitable strategies")
            print(f"\nProfitable Strategy Insights ({len(profitable_strategies)} strategies):")
            
            for param_name, col_name in found_params.items():
                try:
                    if opt_df[col_name].dtype == 'object':
                        # Categorical parameter
                        profitable_methods = profitable_strategies[col_name].value_counts()
                        if len(profitable_methods) > 0:
                            best_method = profitable_methods.index[0]
                            count = profitable_methods.iloc[0]
                            logger.info(f"{param_name}: '{best_method}' most successful ({count} strategies)")
                            print(f"   {param_name}: '{best_method}' most successful ({count} strategies)")
                    else:
                        # Numerical parameter
                        param_data = profitable_strategies[col_name].dropna()
                        if len(param_data) > 0:
                            optimal_range = (param_data.quantile(0.25), param_data.quantile(0.75))
                            logger.info(f"{param_name}: optimal range {optimal_range[0]:.3f} - {optimal_range[1]:.3f}")
                            print(f"   {param_name}: optimal range {optimal_range[0]:.3f} - {optimal_range[1]:.3f}")
                            
                except Exception as e:
                    logger.error(f"Error analyzing {param_name}: {e}")
        else:
            logger.warning("No profitable strategies found for parameter analysis")
            print("\n⚠️ No profitable strategies found for parameter analysis")
            
        # Overall parameter ranges
        print(f"\nOverall Parameter Ranges:")
        for param_name, col_name in found_params.items():
            try:
                if opt_df[col_name].dtype == 'object':
                    unique_values = opt_df[col_name].value_counts().head(3)
                    values_str = ', '.join([f'{v}({c})' for v, c in unique_values.items()])
                    print(f"   {param_name}: {values_str}")
                else:
                    param_clean = opt_df[col_name].dropna()
                    if len(param_clean) > 0:
                        print(f"   {param_name}: {param_clean.min():.3f} - {param_clean.max():.3f}")
            except Exception as e:
                logger.error(f"Error summarizing {param_name}: {e}")
    else:
        logger.warning("No standard parameter columns detected")
        logger.debug(f"Available columns: {', '.join(opt_df.columns[:10])}...")
        print("⚠️ No standard parameter columns detected")
        print(f"Available columns: {', '.join(opt_df.columns[:10])}...")
    
    perf.end_timer('parameter_analysis')
        
else:
    logger.warning("No optimization data available for parameter analysis")
    print("❌ No optimization data available for parameter analysis")

# %% [markdown]
# ## Performance Overview

# %%
# Enhanced time-series performance analysis
if bets_df is not None:
    logger.info("Starting performance time-series analysis...")
    perf.start_timer('performance_analysis')
    
    print("Performance Time-Series Overview")
    print("=" * 50)
    
    try:
        # Detect profit/loss column
        pnl_col = None
        for col in ['net_result', 'profit_loss', 'pnl', 'result']:
            if col in bets_df.columns:
                pnl_col = col
                break
        
        if pnl_col and 'date' in bets_df.columns:
            # Clean and sort data
            bets_clean = bets_df.copy()
            bets_clean[pnl_col] = pd.to_numeric(bets_clean[pnl_col], errors='coerce')
            bets_clean = bets_clean.dropna(subset=[pnl_col, 'date'])
            bets_clean = bets_clean.sort_values('date')
            
            if len(bets_clean) > 0:
                logger.info(f"Analyzing {len(bets_clean)} bet records")
                print(f"Analyzing {len(bets_clean)} bet records")
                
                # Basic statistics
                total_return = bets_clean[pnl_col].sum()
                avg_return = bets_clean[pnl_col].mean()
                
                logger.info(f"Total Return: ${total_return:,.2f}")
                logger.info(f"Average per Bet: ${avg_return:,.2f}")
                
                print(f"\nPerformance Summary:")
                print(f"   Total Return: ${total_return:,.2f}")
                print(f"   Average per Bet: ${avg_return:,.2f}")
                print(f"   Period: {bets_clean['date'].min().strftime('%Y-%m-%d')} to {bets_clean['date'].max().strftime('%Y-%m-%d')}")
                
                # Win rate (if available)
                win_cols = ['bet_won', 'won', 'is_win', 'win']
                win_col = None
                for col in win_cols:
                    if col in bets_clean.columns:
                        win_col = col
                        break
                
                if win_col:
                    try:
                        win_rate = bets_clean[win_col].mean()
                        winning_bets = bets_clean[win_col].sum()
                        logger.info(f"Win Rate: {win_rate:.1%} ({winning_bets}/{len(bets_clean)})")
                        print(f"   Win Rate: {win_rate:.1%} ({winning_bets}/{len(bets_clean)})")
                    except:
                        pass
                
                # Create cumulative return chart
                bets_clean['cumulative_return'] = bets_clean[pnl_col].cumsum()
                
                fig_cumulative = px.line(
                    bets_clean,
                    x='date',
                    y='cumulative_return',
                    title="Cumulative Return Over Time",
                    labels={'cumulative_return': 'Cumulative Return ($)', 'date': 'Date'}
                )
                
                fig_cumulative.add_hline(y=0, line_dash="dash", line_color="red", 
                                       annotation_text="Break-even")
                fig_cumulative.update_layout(height=500)
                
                fig_cumulative.show()
                
                # Enhanced: Automatic chart export using PATHS
                chart_path = PATHS.get_chart_file("cumulative_return", "html")
                fig_cumulative.write_html(chart_path)
                logger.info(f"Chart exported: {chart_path}")
                print(f"Chart saved: {chart_path.name}")
                
            else:
                logger.warning("No valid bet data after cleaning")
                print("⚠️ No valid bet data after cleaning")
        else:
            logger.warning("Required columns (profit/loss and date) not found")
            logger.debug(f"Available columns: {list(bets_df.columns)}")
            print("⚠️ Required columns (profit/loss and date) not found")
            print(f"Available columns: {list(bets_df.columns)}")
    
    except Exception as e:
        logger.error(f"Error in performance analysis: {e}")
        print(f"❌ Error in performance analysis: {e}")
    
    perf.end_timer('performance_analysis')
        
else:
    logger.warning("No backtest data available for performance analysis")
    print("❌ No backtest data available for performance analysis")

# %% [markdown]
# ## Executive Summary

# %%
# Enhanced executive summary with comprehensive logging
logger.info("Generating executive summary...")
perf.start_timer('executive_summary')

print("EXECUTIVE SUMMARY - Hockey Prediction System")
print("=" * 60)

# Collect key metrics
summary_metrics = {}

# Optimization metrics
if opt_df is not None and 'roi' in opt_df.columns:
    summary_metrics['total_strategies'] = len(opt_df)
    summary_metrics['profitable_strategies'] = len(opt_df[opt_df['roi'] > 0])
    summary_metrics['profitability_rate'] = summary_metrics['profitable_strategies'] / summary_metrics['total_strategies']
    summary_metrics['best_roi'] = opt_df['roi'].max()
    summary_metrics['mean_roi'] = opt_df['roi'].mean()
    summary_metrics['median_roi'] = opt_df['roi'].median()
    
    logger.info(f"Summary metrics calculated: {len(summary_metrics)} optimization metrics")

# Backtest metrics
if bets_df is not None:
    pnl_col = None
    for col in ['net_result', 'profit_loss', 'pnl']:
        if col in bets_df.columns:
            pnl_col = col
            break
    
    if pnl_col:
        try:
            bets_clean = bets_df.dropna(subset=[pnl_col])
            summary_metrics['total_bets'] = len(bets_clean)
            summary_metrics['total_return'] = bets_clean[pnl_col].sum()
            
            # Estimate ROI
            if 'stake' in bets_clean.columns:
                total_staked = bets_clean['stake'].sum()
                if total_staked > 0:
                    summary_metrics['actual_roi'] = summary_metrics['total_return'] / total_staked
        except:
            pass

# Print enhanced summary
print("\nKEY PERFORMANCE INDICATORS:")
print("-" * 40)

if 'total_strategies' in summary_metrics:
    print(f"OPTIMIZATION ANALYSIS:")
    print(f"   Strategies Tested: {summary_metrics['total_strategies']:,}")
    print(f"   Profitable Strategies: {summary_metrics['profitable_strategies']:,} ({summary_metrics['profitability_rate']:.1%})")
    print(f"   Best ROI: {summary_metrics['best_roi']:.2%}")
    print(f"   Mean ROI: {summary_metrics['mean_roi']:.2%}")
    print(f"   Median ROI: {summary_metrics['median_roi']:.2%}")
    
    # Log key findings
    logger.info("EXECUTIVE SUMMARY METRICS:")
    for key, value in summary_metrics.items():
        if isinstance(value, float):
            logger.info(f"  {key}: {value:.4f}")
        else:
            logger.info(f"  {key}: {value}")

if 'total_bets' in summary_metrics:
    print(f"\nBACKTEST PERFORMANCE:")
    print(f"   Total Bets Analyzed: {summary_metrics['total_bets']:,}")
    print(f"   Total Return: ${summary_metrics['total_return']:,.2f}")
    if 'actual_roi' in summary_metrics:
        print(f"   Actual ROI: {summary_metrics['actual_roi']:.2%}")

# Enhanced insights and recommendations with logging
print("\nKEY INSIGHTS:")
print("-" * 20)

insights = []

# Profitability insights
if 'profitability_rate' in summary_metrics:
    if summary_metrics['profitability_rate'] > 0.3:
        insight = f"✅ Strong profitability: {summary_metrics['profitability_rate']:.1%} of strategies are profitable"
        insights.append(insight)
    elif summary_metrics['profitability_rate'] > 0.1:
        insight = f"⚠️ Moderate profitability: {summary_metrics['profitability_rate']:.1%} of strategies are profitable"
        insights.append(insight)
    else:
        insight = f"🔴 Low profitability: Only {summary_metrics['profitability_rate']:.1%} of strategies are profitable"
        insights.append(insight)

# ROI insights
if 'best_roi' in summary_metrics:
    if summary_metrics['best_roi'] > 0.2:
        insight = f"✅ Excellent top performance: Best strategy achieves {summary_metrics['best_roi']:.1%} ROI"
        insights.append(insight)
    elif summary_metrics['best_roi'] > 0.05:
        insight = f"✅ Good top performance: Best strategy achieves {summary_metrics['best_roi']:.1%} ROI"
        insights.append(insight)
    else:
        insight = f"⚠️ Limited upside: Best strategy only achieves {summary_metrics['best_roi']:.1%} ROI"
        insights.append(insight)

# Log all insights
for insight in insights:
    print(f"   {insight}")
    logger.info(f"INSIGHT: {insight}")

# Enhanced recommendations
print("\nRECOMMENDATIONS:")
print("-" * 25)

recommendations = []

if 'profitability_rate' in summary_metrics:
    if summary_metrics['profitability_rate'] > 0.2 and summary_metrics.get('best_roi', 0) > 0.1:
        recommendations.extend([
            "1. ✅ Proceed with live testing using top 5-10 strategies",
            "2. 📊 Implement strict risk management (max 2% per bet)",
            "3. 🔄 Monitor performance and adjust parameters monthly"
        ])
    elif summary_metrics['profitability_rate'] > 0.1:
        recommendations.extend([
            "1. ⚠️ Paper trade top strategies before real money",
            "2. 🔍 Focus only on top 5% of strategies",
            "3. 📉 Use very conservative stake sizes (1% max)"
        ])
    else:
        recommendations.extend([
            "1. 🔴 Do NOT proceed with live trading yet",
            "2. 🔬 Investigate model accuracy and edge detection",
            "3. 📚 Consider alternative approaches or markets"
        ])
else:
    recommendations.append("1. 📊 Need more comprehensive optimization data for recommendations")

# Log all recommendations
for recommendation in recommendations:
    print(f"   {recommendation}")
    logger.info(f"RECOMMENDATION: {recommendation}")

# Enhanced analysis metadata
analysis_timestamp = datetime.now()
print(f"\nAnalysis completed: {analysis_timestamp.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Charts exported to: {CHARTS_EXPORT_DIR}")

# Data sources used
data_sources = []
if opt_source:
    data_sources.append(f"Optimization: {opt_source}")
if bets_source:
    data_sources.append(f"Backtest: {bets_source}")

if data_sources:
    print(f"Data sources: {', '.join(data_sources)}")
    logger.info(f"Data sources used: {', '.join(data_sources)}")

# Log executive summary completion
logger.info("Executive summary completed successfully")
logger.info(f"Analysis timestamp: {analysis_timestamp}")
logger.info(f"Insights generated: {len(insights)}")
logger.info(f"Recommendations generated: {len(recommendations)}")

perf.end_timer('executive_summary')

print("\nAnalysis Summary: Main overview completed successfully!")
print("For detailed analysis, run specialized notebooks:")
print("   - strategy_optimization.ipynb (parameter deep dive)")
print("   - risk_assessment.ipynb (drawdown & risk metrics)")
print("   - model_validation.ipynb (prediction performance)")

# %% [markdown]
# ## Enhanced Export & Results

# %%
# Enhanced export with automatic timestamping and safe file handling
logger.info("Starting enhanced export process...")
perf.start_timer('export_process')

# Create enhanced summary dashboard
def create_enhanced_summary_dashboard():
    """Create a comprehensive summary dashboard with enhanced features"""
    
    if opt_df is None:
        logger.warning("Cannot create dashboard - no optimization data")
        print("❌ Cannot create dashboard - no optimization data")
        return None
    
    try:
        logger.info("Creating enhanced summary dashboard...")
        
        # Create 2x2 dashboard
        fig = make_subplots(
            rows=2, cols=2,
            subplot_titles=('ROI Distribution', 'Top 10 Strategies', 
                          'Performance Over Time', 'Summary Stats'),
            specs=[[{"type": "histogram"}, {"type": "bar"}],
                   [{"type": "scatter"}, {"type": "table"}]]
        )
        
        # 1. ROI Distribution
        fig.add_trace(
            go.Histogram(x=opt_df['roi'], name='ROI Distribution', nbinsx=30),
            row=1, col=1
        )
        
        # 2. Top 10 ROIs
        top_10 = opt_df.nlargest(10, 'roi')
        fig.add_trace(
            go.Bar(x=list(range(1, 11)), y=top_10['roi'], name='Top 10 ROIs'),
            row=1, col=2
        )
        
        # 3. Performance over time (if bet data available)
        if bets_df is not None and 'date' in bets_df.columns:
            pnl_col = None
            for col in ['net_result', 'profit_loss', 'pnl']:
                if col in bets_df.columns:
                    pnl_col = col
                    break
            
            if pnl_col:
                try:
                    bets_sample = bets_df.dropna(subset=[pnl_col, 'date']).head(1000)
                    bets_sample = bets_sample.sort_values('date')
                    cumulative = bets_sample[pnl_col].cumsum()
                    
                    fig.add_trace(
                        go.Scatter(x=bets_sample['date'], y=cumulative, 
                                 mode='lines', name='Cumulative Return'),
                        row=2, col=1
                    )
                except Exception as e:
                    logger.error(f"Error adding performance chart to dashboard: {e}")
        
        # 4. Enhanced summary table
        summary_data = [
            ['Strategies Tested', f"{len(opt_df):,}"],
            ['Profitable', f"{len(opt_df[opt_df['roi'] > 0]):,}"],
            ['Best ROI', f"{opt_df['roi'].max():.2%}"],
            ['Mean ROI', f"{opt_df['roi'].mean():.2%}"],
            ['Median ROI', f"{opt_df['roi'].median():.2%}"]
        ]
        
        fig.add_trace(
            go.Table(
                header=dict(values=['Metric', 'Value']),
                cells=dict(values=[[row[0] for row in summary_data], 
                                  [row[1] for row in summary_data]])
            ),
            row=2, col=2
        )
        
        fig.update_layout(
            height=800,
            title_text="Hockey Prediction System - Enhanced Summary Dashboard",
            showlegend=False
        )
        
        # Enhanced: Save dashboard using PATHS
        dashboard_path = PATHS.get_chart_file('enhanced_summary_dashboard', 'html')
        fig.write_html(dashboard_path)
        
        logger.info(f"Enhanced dashboard created: {dashboard_path}")
        return dashboard_path
        
    except Exception as e:
        logger.error(f"Error creating enhanced summary dashboard: {e}")
        print(f"⚠️ Error creating enhanced summary dashboard: {e}")
        return None

# Create enhanced dashboard
dashboard_path = create_enhanced_summary_dashboard()

if dashboard_path:
    print(f"✅ Enhanced summary dashboard created: {dashboard_path.name}")
    print(f"🌐 Open in browser: file://{dashboard_path.absolute()}")

# Enhanced results export using safe file handlers
if 'summary_metrics' in locals():
    try:
        # Create comprehensive results summary
        results_summary = {
            'analysis_metadata': {
                'timestamp': analysis_timestamp.isoformat(),
                'component': 'analysis',
                'notebook': 'main_analysis.ipynb',
                'data_sources': {
                    'optimization': opt_source,
                    'backtest': bets_source
                }
            },
            'summary_metrics': summary_metrics,
            'insights': insights,
            'recommendations': recommendations
        }
        
        # Enhanced export using PATHS + safe file handlers
        from src.utils.file_handlers import write_json
        
        results_file = PATHS.processed_data / f"main_analysis_results_{analysis_timestamp.strftime('%Y%m%d_%H%M%S')}.json"
        write_json(results_summary, results_file, indent=2)
        
        logger.info(f"Enhanced results exported: {results_file}")
        print(f"📋 Enhanced results saved: {results_file.name}")
        
    except Exception as e:
        logger.error(f"Error exporting enhanced results: {e}")
        print(f"⚠️ Error exporting enhanced results: {e}")

# List all exported files
print("\nExported Files:")
chart_files = list(CHARTS_EXPORT_DIR.glob("*.html"))
for chart_file in sorted(chart_files):
    size_kb = chart_file.stat().st_size / 1024
    print(f"  📊 {chart_file.name} ({size_kb:.1f}KB)")
    logger.info(f"Chart exported: {chart_file.name} ({size_kb:.1f}KB)")

perf.end_timer('export_process')

# Final enhanced summary logging
logger.info("=" * 60)
logger.info("ENHANCED MAIN ANALYSIS COMPLETED")
logger.info(f"  Total processing time: {sum(perf.timers.values()) if hasattr(perf, 'timers') else 'N/A'}")
logger.info(f"  Charts exported: {len(chart_files)}")
logger.info(f"  Component logging: logs/analysis.log")
logger.info(f"  Centralized paths: {PATHS.root}")
logger.info("=" * 60)

print(f"\n🎯 Enhanced main analysis completed!")
print(f"📁 {len(chart_files)} charts exported to: {CHARTS_EXPORT_DIR}")
print(f"📝 Component logs: logs/analysis.log")
print(f"\n📚 Next steps:")
print(f"   1. Review enhanced dashboard for key insights")
print(f"   2. Run specialized notebooks for detailed analysis")
print(f"   3. Implement recommended strategies based on findings")

# %% [markdown]
# ---
#
# ## Enhanced Main Analysis Summary
#
# This enhanced notebook provides comprehensive backtesting analysis with:
#
# ✅ **Enhanced Infrastructure** - Centralized paths + per-component logging (`logs/analysis.log`)
# ✅ **Safe File Handling** - Automatic encoding detection + error handling
# ✅ **Performance Monitoring** - Operation timing and debugging capabilities
# ✅ **Strategy Performance Overview** - ROI analysis with enhanced logging
# ✅ **Interactive Visualizations** - Auto-exported charts with proper paths
# ✅ **Executive Summary** - Comprehensive insights with actionable recommendations
# ✅ **Enhanced Export** - Automatic timestamping + centralized file management
#
# ## 🔧 Enhanced Features
#
# - **All-in-One Setup**: `notebook_setup_complete()` replaces complex path hackování
# - **Component Logging**: Per-component log files for better debugging
# - **PATHS Integration**: Centralized path management across all operations
# - **Safe Encoding**: Automatic encoding detection for robust file loading
# - **Performance Tracking**: Built-in timing for optimization insights
# - **Interactive Development**: Enhanced debugging and cell-by-cell execution
#
# ## 📁 Installation & Usage
#
# **Save as:** `notebooks/analysis/main_analysis.ipynb`
# **Requirements:** Enhanced infrastructure must be installed (`pip install -e .`)
#
# **Usage:**
# 1. Run first cell for enhanced setup
# 2. Execute cells sequentially
# 3. Check `logs/analysis.log` for detailed debugging info
# 4. View exported charts in `models/experiments/charts/`
#
# ## 🔗 Related Notebooks
#
# - **strategy_optimization.ipynb** - Deep parameter analysis
# - **risk_assessment.ipynb** - Comprehensive risk metrics
# - **model_validation.ipynb** - Prediction accuracy analysis
#
# ---
#
# *Hockey Prediction System - Enhanced Main Backtesting Analysis*
# *Enhanced with centralized infrastructure and per-component logging*
# *Location: notebooks/analysis/main_analysis.ipynb*
