# %% [markdown]
# # Hockey Prediction System - Risk Assessment Analysis (ENHANCED)
#
# **Comprehensive Risk Assessment for Hockey Betting Strategies**
#
# **Enhanced Infrastructure:** Centralized paths via `PATHS`, per-component logging (`logs/analysis.log`), safe file handling, reuse of `src/betting/risk_metrics.py`
#
# ---
#
# ## Analysis Structure
#
# 1. **Setup & Data Pipeline** - Enhanced infrastructure, data loading via `file_handlers`
# 2. **Core Risk Analysis** - Drawdown, Monte Carlo VaR, risk-adjusted metrics (Sharpe, Sortino, Calmar, Omega)
# 3. **Portfolio & Recovery Analysis** - Correlation, diversification, recovery patterns
# 4. **Summary & Export** - Executive summary, visualizations, reports
#
# **Location:** `notebooks/analysis/risk_assessment.ipynb`
# **Component:** `analysis` -> `logs/analysis.log`
#
# ---

# %% [markdown]
# ---
# # PART 1: SETUP & DATA PIPELINE
#
# ---

# %%
# === ENHANCED SETUP ===
from src.utils.notebook_helper import notebook_setup_complete

env = notebook_setup_complete(
    component='analysis',
    import_libraries=True,
    sample_data=None
)

PATHS = env['PATHS']
logger = env['logger']
pd = env['pd']
np = env['np']
plt = env['plt']
perf = env['performance_tracker']

# Additional imports
import json
import re
import warnings
from datetime import datetime, timedelta
from typing import Dict, List, Any, Optional
from scipy import stats
from scipy.stats import norm

try:
    import plotly.graph_objects as go
    import plotly.express as px
    from plotly.subplots import make_subplots
    PLOTLY_AVAILABLE = True
except ImportError:
    PLOTLY_AVAILABLE = False
    logger.warning("Plotly not available - interactive charts will be skipped")

# Reuse risk metric functions from src/
from src.betting.risk_metrics import (
    calculate_sharpe_ratio,
    calculate_sortino_ratio,
    calculate_var_metrics,
    calculate_drawdown_metrics,
    calculate_recovery_periods,
)
from src.utils.file_handlers import read_csv, read_json, write_json

warnings.filterwarnings('ignore')

# Paths
RESULTS_DIR = PATHS.experiments
CHARTS_EXPORT_DIR = PATHS.model_charts

logger.info("Risk Assessment Analysis started")
logger.info(f"Results directory: {RESULTS_DIR}")
print(f"Enhanced notebook ready! Component: {env['component']}")

# %%
# === DATA LOADING (using enhanced file_handlers) ===

logger.info("Loading data files...")
perf.start_timer('data_loading')

DATA_PATTERNS = {
    'top_strategies_bets': 'backtest_top_strategies_bets_*.csv',
    'top_strategies_daily': 'backtest_top_strategies_daily_financial_*.csv',
    'top_strategies_monthly': 'backtest_top_strategies_monthly_*.csv',
    'strategy_correlations': 'backtest_strategy_correlation_*.csv',
    'top_strategies_summary': 'backtest_top_strategies_summary_*.json',
}


def load_all_data(results_dir, patterns):
    """Load all available data files using enhanced file handlers"""
    loaded_data = {}

    for data_type, pattern in patterns.items():
        files = sorted(results_dir.glob(pattern), key=lambda f: f.stat().st_mtime, reverse=True)
        if not files:
            logger.debug(f"No files found for {pattern}")
            continue

        latest_file = files[0]
        try:
            if latest_file.suffix == '.csv':
                df = read_csv(latest_file)
                if len(df) > 0:
                    loaded_data[data_type] = df
                    logger.info(f"Loaded {data_type}: {len(df):,} rows from {latest_file.name}")
            elif latest_file.suffix == '.json':
                data = read_json(latest_file)
                loaded_data[data_type] = data
                logger.info(f"Loaded {data_type}: JSON from {latest_file.name}")
        except Exception as e:
            logger.error(f"Error loading {latest_file.name}: {e}")

    logger.info(f"Files loaded: {len(loaded_data)}/{len(patterns)}")
    return loaded_data


DATA = load_all_data(RESULTS_DIR, DATA_PATTERNS)
perf.end_timer('data_loading')

print(f"Data loaded: {len(DATA)}/{len(DATA_PATTERNS)} datasets")
for key in DATA:
    if isinstance(DATA[key], pd.DataFrame):
        print(f"  {key}: {len(DATA[key]):,} rows")
    else:
        print(f"  {key}: JSON")

# %%
# === DATA STRUCTURE DIAGNOSTICS ===

print("DATA STRUCTURE DIAGNOSTICS")
print("=" * 70)

if 'top_strategies_bets' in DATA:
    bets_df = DATA['top_strategies_bets']
    print(f"\nBET DATA: {len(bets_df):,} rows")
    print(f"  Columns: {list(bets_df.columns)}")

    id_col = 'strategy_id' if 'strategy_id' in bets_df.columns else None
    if id_col:
        unique_strategies = bets_df[id_col].unique()
        print(f"  Unique strategies: {len(unique_strategies)}")
        for strat in unique_strategies[:5]:
            count = len(bets_df[bets_df[id_col] == strat])
            print(f"    - {strat}: {count} bets")

if 'top_strategies_daily' in DATA:
    daily_df = DATA['top_strategies_daily']
    print(f"\nDAILY DATA: {len(daily_df):,} rows")
    print(f"  Columns: {list(daily_df.columns)}")

    return_cols = [c for c in daily_df.columns if 'roi' in c.lower() or 'return' in c.lower()]
    if return_cols:
        print(f"  Return columns: {return_cols}")
    else:
        numeric_cols = daily_df.select_dtypes(include=[np.number]).columns.tolist()
        print(f"  No return columns found. Numeric: {numeric_cols}")

# Consistency check
if 'top_strategies_bets' in DATA and 'top_strategies_daily' in DATA:
    bets_strats = set(DATA['top_strategies_bets'].get('strategy_id', pd.Series()).unique())
    daily_id_col = 'strategy_id' if 'strategy_id' in DATA['top_strategies_daily'].columns else 'strategy'
    daily_strats = set(DATA['top_strategies_daily'].get(daily_id_col, pd.Series()).unique())
    common = bets_strats & daily_strats
    print(f"\nCONSISTENCY: {len(common)} common strategies "
          f"(bets: {len(bets_strats)}, daily: {len(daily_strats)})")

logger.info("Data diagnostics completed")

# %%
# === STRATEGY SELECTION & VALIDATION ===

logger.info("Selecting strategies...")
perf.start_timer('strategy_selection')

MIN_BETS = 50
MIN_ROI = -0.20
MAX_STRATEGIES = 20


def select_strategies(data, min_bets=MIN_BETS, min_roi=MIN_ROI, max_strategies=MAX_STRATEGIES):
    """Select and validate top strategies"""
    if 'top_strategies_bets' not in data:
        logger.warning("No bet data available")
        return {'error': 'No bet data available'}

    bet_data = data['top_strategies_bets'].copy()

    # Determine strategy column
    if 'strategy_id' in bet_data.columns:
        bet_data['strategy'] = bet_data['strategy_id']
    elif 'strategy_index' in bet_data.columns:
        bet_data['strategy'] = 'Strategy_' + bet_data['strategy_index'].astype(str)
    else:
        logger.error("No strategy identifier found")
        return {'error': 'No strategy identifier'}

    # Calculate per-strategy metrics
    strategy_stats = []
    for strategy, group in bet_data.groupby('strategy'):
        total_bets = len(group)
        wins = (group['bet_won'] == True).sum() if 'bet_won' in group.columns else 0
        win_rate = wins / total_bets if total_bets > 0 else 0

        if 'net_result' in group.columns and 'stake' in group.columns:
            total_profit = group['net_result'].sum()
            total_stake = group['stake'].sum()
            roi = total_profit / total_stake if total_stake > 0 else 0

            returns = group['net_result'] / group['stake']
            # Use src/ functions for risk metrics
            sharpe = calculate_sharpe_ratio(returns, periods_per_year=252)
            cumulative_pnl = group['net_result'].cumsum()
            dd_metrics = calculate_drawdown_metrics(cumulative_pnl)
            max_dd = dd_metrics['max_drawdown_percent']
        else:
            roi = sharpe = max_dd = 0

        strategy_stats.append({
            'strategy': str(strategy),
            'total_bets': total_bets,
            'win_rate': win_rate,
            'roi': roi,
            'max_drawdown': max_dd,
            'sharpe_ratio': sharpe
        })

    stats_df = pd.DataFrame(strategy_stats)
    if stats_df.empty:
        return {'error': 'No strategies found'}

    logger.info(f"Total strategies: {len(stats_df)}")

    # Filter
    filtered = stats_df[
        (stats_df['total_bets'] >= min_bets) &
        (stats_df['roi'] >= min_roi)
    ].copy()

    logger.info(f"After filtering: {len(filtered)}")

    if len(filtered) == 0:
        return {'error': 'No strategies meet criteria'}

    # Composite score
    filtered['composite_score'] = (
        filtered['roi'] * 0.4 +
        filtered['sharpe_ratio'] * 0.3 +
        filtered['win_rate'] * 0.2 +
        (1 / (filtered['max_drawdown'].abs() + 0.01)) * 0.1
    )

    top = filtered.nlargest(max_strategies, 'composite_score')

    print(f"TOP {len(top)} STRATEGIES:")
    print("-" * 80)
    for i, (_, s) in enumerate(top.iterrows(), 1):
        print(f"{i:2d}. {s['strategy'][:40]:<40} | "
              f"ROI: {s['roi']:+6.1%} | Bets: {s['total_bets']:4.0f} | "
              f"Win Rate: {s['win_rate']:5.1%}")

    return {
        'selected_strategies': top,
        'all_strategies': stats_df,
        'summary': {
            'total_found': len(stats_df),
            'total_selected': len(top),
            'avg_roi': top['roi'].mean(),
            'avg_win_rate': top['win_rate'].mean(),
        }
    }


STRATEGY_SELECTION = select_strategies(DATA)
perf.end_timer('strategy_selection')

# %%
# === PART 1 SUMMARY ===

print("=" * 80)
print("PART 1: SETUP & DATA PIPELINE - COMPLETE")
print("=" * 80)

print(f"Data loaded: {len(DATA)} datasets")

if 'selected_strategies' in STRATEGY_SELECTION:
    s = STRATEGY_SELECTION['summary']
    print(f"Strategies selected: {s['total_selected']} (from {s['total_found']})")
    print(f"  Average ROI: {s['avg_roi']:+.1%}")
    print(f"  Average Win Rate: {s['avg_win_rate']:.1%}")
elif 'error' in STRATEGY_SELECTION:
    print(f"Strategy selection: {STRATEGY_SELECTION['error']}")

print(f"\nAvailable datasets:")
for key in ['top_strategies_bets', 'top_strategies_daily', 'top_strategies_monthly', 'strategy_correlations']:
    status = 'OK' if key in DATA else 'N/A'
    print(f"  {key}: {status}")

logger.info("Part 1 complete")

# %% [markdown]
# ---
#
# # ⚠️ PART 2: CORE RISK ANALYSIS
#
# **Maximum drawdown, Monte Carlo VaR, and risk-adjusted performance metrics**
#
# ---

# %%
# === PART 2: CORE RISK ANALYSIS ===

if 'error' in STRATEGY_SELECTION:
    print(f"Cannot proceed: {STRATEGY_SELECTION['error']}")
    raise RuntimeError("Part 1 data required")

logger.info("Starting Part 2: Core Risk Analysis")
print("Starting Part 2: Core Risk Analysis")

# %%
# === RISK METRICS HELPERS ===
# Sharpe, Sortino imported from src/betting/risk_metrics.py in setup cell.
# Only define functions not available in src/:


def calculate_calmar_ratio(returns, max_drawdown):
    """Calmar ratio = annualized return / max drawdown"""
    if max_drawdown == 0:
        return float('inf') if returns.mean() > 0 else 0.0
    annual_return = returns.mean() * 252
    return annual_return / abs(max_drawdown)


def calculate_omega_ratio(returns, threshold=0.0):
    """Omega ratio = sum(gains above threshold) / sum(losses below threshold)"""
    excess = returns - threshold
    gains = excess[excess > 0].sum()
    losses = abs(excess[excess <= 0].sum())
    if losses == 0:
        return float('inf') if gains > 0 else 0.0
    return gains / losses


def calculate_drawdown_series(returns):
    """Calculate drawdown series from returns"""
    cumulative = (1 + returns).cumprod()
    running_max = cumulative.expanding().max()
    return (cumulative - running_max) / running_max


def get_strategy_returns(daily_data, strategy_name):
    """Extract returns series for a strategy from daily data"""
    # Determine strategy column
    strat_col = None
    for col in ['strategy', 'strategy_id']:
        if col in daily_data.columns:
            strat_col = col
            break
    if strat_col is None:
        return None

    sdata = daily_data[daily_data[strat_col] == strategy_name].copy()
    if len(sdata) < 10:
        return None

    sdata = sdata.sort_values('date')

    # Find returns column
    for col in ['daily_roi', 'daily_return', 'roi', 'return', 'net_return']:
        if col in sdata.columns:
            returns = sdata[col].copy()
            returns.index = pd.to_datetime(sdata['date'])
            return returns

    # Fallback: calculate from net_result/stake
    if 'net_result' in sdata.columns and 'stake' in sdata.columns:
        returns = (sdata['net_result'] / sdata['stake']).copy()
        returns.index = pd.to_datetime(sdata['date'])
        return returns

    return None


print("Risk metrics helpers defined (Calmar, Omega, drawdown_series, strategy returns)")

# %%
# === DRAWDOWN ANALYSIS ===

logger.info("Starting drawdown analysis...")
perf.start_timer('drawdown_analysis')


def analyze_strategy_drawdown(returns, strategy_name):
    """Analyze drawdown for a single strategy"""
    if returns is None or len(returns) < 2:
        return {'error': 'Insufficient data'}

    dd_series = calculate_drawdown_series(returns)
    max_dd_idx = dd_series.idxmin()
    max_dd = dd_series.min()

    # Find recovery point
    recovery_idx = None
    if max_dd_idx in dd_series.index:
        post_dd = dd_series.loc[max_dd_idx:]
        recovery_mask = post_dd >= -0.001
        if recovery_mask.any():
            recovery_idx = post_dd[recovery_mask].index[0]

    # Durations
    pre_dd = dd_series[:max_dd_idx]
    start_mask = pre_dd >= -0.001
    dd_start = pre_dd[start_mask].index[-1] if start_mask.any() else dd_series.index[0]

    dd_days = (max_dd_idx - dd_start).days if hasattr(max_dd_idx - dd_start, 'days') else len(pre_dd)
    rec_days = (recovery_idx - max_dd_idx).days if recovery_idx and hasattr(recovery_idx - max_dd_idx, 'days') else None

    return {
        'strategy_name': strategy_name,
        'max_drawdown': max_dd,
        'max_drawdown_pct': max_dd * 100,
        'drawdown_duration_days': dd_days,
        'recovery_duration_days': rec_days,
        'is_recovered': recovery_idx is not None,
        'time_underwater_pct': (dd_series < -0.01).sum() / len(dd_series) * 100,
        'volatility_annualized': returns.std() * np.sqrt(252),
        'drawdown_series': dd_series
    }


def run_drawdown_analysis(data, strategy_selection):
    """Run drawdown analysis for all selected strategies"""
    if 'top_strategies_daily' not in data or 'error' in strategy_selection:
        return {'error': 'Missing data or strategies'}

    daily_data = data['top_strategies_daily']
    selected = strategy_selection['selected_strategies']
    results = {}
    summary_rows = []

    for strategy_name in selected['strategy'].tolist():
        returns = get_strategy_returns(daily_data, strategy_name)
        dd = analyze_strategy_drawdown(returns, strategy_name)

        if 'error' not in dd:
            results[strategy_name] = dd
            summary_rows.append({
                'strategy': strategy_name,
                'max_drawdown_pct': dd['max_drawdown_pct'],
                'drawdown_duration_days': dd['drawdown_duration_days'],
                'recovery_duration_days': dd['recovery_duration_days'],
                'is_recovered': dd['is_recovered'],
                'time_underwater_pct': dd['time_underwater_pct']
            })
            logger.info(f"{strategy_name[:40]}: DD={dd['max_drawdown_pct']:.1f}%, "
                        f"Duration={dd['drawdown_duration_days']}d, "
                        f"Recovery={dd['recovery_duration_days'] or 'Ongoing'}")

    summary_df = pd.DataFrame(summary_rows) if summary_rows else pd.DataFrame()
    portfolio_summary = {}
    if len(summary_df) > 0:
        portfolio_summary = {
            'total_analyzed': len(results),
            'avg_max_drawdown': summary_df['max_drawdown_pct'].mean(),
            'worst_drawdown': summary_df['max_drawdown_pct'].min(),
            'recovery_rate': summary_df['is_recovered'].mean() * 100
        }
        print(f"\nDRAWDOWN SUMMARY ({len(results)} strategies):")
        print(f"  Average max drawdown: {portfolio_summary['avg_max_drawdown']:.1f}%")
        print(f"  Worst drawdown: {portfolio_summary['worst_drawdown']:.1f}%")
        print(f"  Recovery rate: {portfolio_summary['recovery_rate']:.1f}%")

    return {
        'individual_results': results,
        'summary_statistics': summary_df,
        'portfolio_summary': portfolio_summary,
    }


DRAWDOWN_RESULTS = run_drawdown_analysis(DATA, STRATEGY_SELECTION)
perf.end_timer('drawdown_analysis')

# %%
# === MONTE CARLO VaR ANALYSIS ===

logger.info("Starting Monte Carlo VaR analysis...")
perf.start_timer('var_analysis')

N_SIMULATIONS = 10_000


def calculate_monte_carlo_var(returns, n_simulations=N_SIMULATIONS,
                              confidence_levels=(0.95, 0.99)):
    """Calculate VaR using historical percentiles and Monte Carlo bootstrap"""
    if len(returns) < 30:
        return {'error': 'Insufficient data'}

    # Historical VaR via src/
    hist_var = calculate_var_metrics(returns)

    # Monte Carlo (bootstrap resampling)
    simulated = np.random.choice(returns, size=(n_simulations, len(returns)), replace=True)
    portfolio_returns = simulated.sum(axis=1)

    mc_var = {}
    mc_cvar = {}
    for conf in confidence_levels:
        var_level = np.percentile(portfolio_returns, (1 - conf) * 100)
        cvar_level = portfolio_returns[portfolio_returns <= var_level].mean()
        mc_var[f'{conf:.0%}'] = var_level / len(returns)
        mc_cvar[f'{conf:.0%}'] = cvar_level / len(returns)

    return {
        'historical_var': hist_var,
        'monte_carlo_var': mc_var,
        'monte_carlo_cvar': mc_cvar,
        'distribution_metrics': {
            'mean': portfolio_returns.mean() / len(returns),
            'std': portfolio_returns.std() / len(returns),
            'skewness': float(stats.skew(portfolio_returns)),
            'kurtosis': float(stats.kurtosis(portfolio_returns)),
            'prob_loss': float((portfolio_returns < 0).mean())
        }
    }


def run_var_analysis(data, strategy_selection):
    """Run VaR analysis for all selected strategies"""
    if 'top_strategies_daily' not in data or 'error' in strategy_selection:
        return {'error': 'Missing data or strategies'}

    daily_data = data['top_strategies_daily']
    selected = strategy_selection['selected_strategies']
    individual = {}

    for strategy_name in selected['strategy'].tolist():
        returns = get_strategy_returns(daily_data, strategy_name)
        if returns is None or len(returns) < 30:
            continue

        var_result = calculate_monte_carlo_var(returns)
        if 'error' not in var_result:
            var_result['strategy_name'] = strategy_name
            individual[strategy_name] = var_result
            logger.info(f"{strategy_name[:40]}: "
                        f"VaR95={var_result['monte_carlo_var']['95%']:+.2%}, "
                        f"P(loss)={var_result['distribution_metrics']['prob_loss']:.1%}")

    # Summary
    summary = {}
    if individual:
        var95 = [r['monte_carlo_var']['95%'] for r in individual.values()]
        var99 = [r['monte_carlo_var']['99%'] for r in individual.values()]
        summary = {
            'total_strategies': len(individual),
            'avg_var_95': np.mean(var95),
            'worst_var_95': min(var95),
            'avg_var_99': np.mean(var99),
            'worst_var_99': min(var99),
        }
        print(f"\nVaR SUMMARY ({len(individual)} strategies, {N_SIMULATIONS:,} simulations):")
        print(f"  Average VaR 95%: {summary['avg_var_95']:+.2%}")
        print(f"  Worst VaR 95%: {summary['worst_var_95']:+.2%}")

    return {
        'individual_results': individual,
        'summary_statistics': summary,
        'simulation_parameters': {'n_simulations': N_SIMULATIONS},
    }


VAR_RESULTS = run_var_analysis(DATA, STRATEGY_SELECTION)
perf.end_timer('var_analysis')

# %%
# === RISK-ADJUSTED PERFORMANCE METRICS ===

logger.info("Starting risk-adjusted performance analysis...")
perf.start_timer('performance_analysis')

RISK_FREE_RATE = 0.02


def analyze_strategy_performance(returns, max_drawdown, risk_free_rate=RISK_FREE_RATE):
    """Calculate all risk-adjusted performance metrics using src/ functions"""
    return {
        'annual_return': float(returns.mean() * 252),
        'annual_volatility': float(returns.std() * np.sqrt(252)),
        'sharpe_ratio': calculate_sharpe_ratio(returns, risk_free_rate, periods_per_year=252),
        'sortino_ratio': calculate_sortino_ratio(returns, periods_per_year=252),
        'calmar_ratio': calculate_calmar_ratio(returns, max_drawdown),
        'omega_ratio': calculate_omega_ratio(returns),
        'max_drawdown': max_drawdown,
        'total_return': float((1 + returns).prod() - 1),
        'positive_days_pct': float((returns > 0).mean()),
        'skewness': float(stats.skew(returns)),
        'kurtosis': float(stats.kurtosis(returns)),
    }


def run_performance_analysis(data, strategy_selection, drawdown_results):
    """Run performance analysis for all strategies"""
    if 'top_strategies_daily' not in data or 'error' in strategy_selection:
        return {'error': 'Missing data or strategies'}

    daily_data = data['top_strategies_daily']
    selected = strategy_selection['selected_strategies']
    results = {}
    rows = []

    for strategy_name in selected['strategy'].tolist():
        returns = get_strategy_returns(daily_data, strategy_name)
        if returns is None or len(returns) < 10:
            continue

        # Get drawdown from previous analysis
        max_dd = 0
        if ('individual_results' in drawdown_results and
                strategy_name in drawdown_results['individual_results']):
            max_dd = abs(drawdown_results['individual_results'][strategy_name]['max_drawdown'])
        else:
            dd_series = calculate_drawdown_series(returns)
            max_dd = abs(dd_series.min())

        metrics = analyze_strategy_performance(returns, max_dd)
        metrics['strategy_name'] = strategy_name
        metrics['total_days'] = len(returns)
        results[strategy_name] = metrics
        rows.append(metrics)

        logger.info(f"{strategy_name[:40]}: Sharpe={metrics['sharpe_ratio']:.2f}, "
                    f"Return={metrics['annual_return']:+.1%}")

    summary_df = pd.DataFrame(rows) if rows else pd.DataFrame()
    portfolio_summary = {}

    if len(summary_df) > 0:
        portfolio_summary = {
            'total_strategies': len(rows),
            'avg_sharpe': summary_df['sharpe_ratio'].mean(),
            'avg_sortino': summary_df['sortino_ratio'].mean(),
            'avg_annual_return': summary_df['annual_return'].mean(),
            'avg_annual_vol': summary_df['annual_volatility'].mean(),
        }
        print(f"\nPERFORMANCE SUMMARY ({len(rows)} strategies):")
        print(f"  Average Sharpe: {portfolio_summary['avg_sharpe']:.2f}")
        print(f"  Average Annual Return: {portfolio_summary['avg_annual_return']:+.1%}")

    return {
        'individual_results': results,
        'summary_statistics': summary_df,
        'portfolio_summary': portfolio_summary,
    }


PERFORMANCE_RESULTS = run_performance_analysis(DATA, STRATEGY_SELECTION, DRAWDOWN_RESULTS)
perf.end_timer('performance_analysis')

# %%
# ===================================================================
# 📋 PART 2 COMPLETION SUMMARY
# ===================================================================

print(f"\n" + "=" * 80)
print("📋 PART 2: CORE RISK ANALYSIS - COMPLETION SUMMARY")
print("=" * 80)

# Drawdown Analysis Summary
if 'individual_results' in DRAWDOWN_RESULTS:
    dd_count = len(DRAWDOWN_RESULTS['individual_results'])
    avg_dd = DRAWDOWN_RESULTS.get('portfolio_summary', {}).get('avg_max_drawdown', 0)
    recovery_rate = DRAWDOWN_RESULTS.get('portfolio_summary', {}).get('recovery_rate', 0)
    
    print(f"✅ Maximum Drawdown Analysis:")
    print(f"   - Strategies analyzed: {dd_count}")
    print(f"   - Average max drawdown: {avg_dd:.1f}%")
    print(f"   - Recovery rate: {recovery_rate:.1f}%")

# VaR Analysis Summary  
if 'individual_results' in VAR_RESULTS:
    var_count = len(VAR_RESULTS['individual_results'])
    avg_var = VAR_RESULTS.get('summary_statistics', {}).get('avg_var_95', 0)
    n_sims = VAR_RESULTS.get('simulation_parameters', {}).get('n_simulations', 0)
    
    print(f"✅ Monte Carlo VaR Analysis:")
    print(f"   - Strategies analyzed: {var_count}")
    print(f"   - Simulations performed: {n_sims:,}")
    print(f"   - Average VaR 95%: {avg_var:+.1%}")

# Performance Analysis Summary
if 'individual_results' in PERFORMANCE_RESULTS:
    perf_count = len(PERFORMANCE_RESULTS['individual_results'])
    avg_sharpe = PERFORMANCE_RESULTS.get('portfolio_summary', {}).get('avg_sharpe_ratio', 0)
    avg_return = PERFORMANCE_RESULTS.get('portfolio_summary', {}).get('avg_annual_return', 0)
    
    print(f"✅ Risk-Adjusted Performance Analysis:")
    print(f"   - Strategies analyzed: {perf_count}")
    print(f"   - Average Sharpe ratio: {avg_sharpe:.2f}")
    print(f"   - Average annual return: {avg_return:+.1%}")

print(f"\n💾 Session data available:")
print(f"   - DRAWDOWN_RESULTS: Maximum drawdown analysis")
print(f"   - VAR_RESULTS: Monte Carlo VaR simulations")
print(f"   - PERFORMANCE_RESULTS: Risk-adjusted performance metrics")

print(f"\n🎯 Ready to proceed to Part 3: Portfolio & Recovery Analysis")
print("=" * 80)

# %% [markdown]
# ---
#
# # 🔗 PART 3: PORTFOLIO & RECOVERY ANALYSIS
#
# **Correlation analysis, diversification insights, and recovery patterns**
#
# ---

# %%
# ===================================================================
# RISK ASSESSMENT - PART 3: PORTFOLIO & RECOVERY ANALYSIS
# ===================================================================

# Verify previous parts data availability
required_vars = ['DATA', 'STRATEGY_SELECTION', 'DRAWDOWN_RESULTS', 'VAR_RESULTS', 'PERFORMANCE_RESULTS']
missing_vars = [v for v in required_vars if v not in globals()]

print("Checking required variables from previous parts...")
for var in required_vars:
    status = "available" if var in globals() else "MISSING"
    print(f"  {var}: {status}")

if missing_vars:
    raise RuntimeError(f"Missing data from previous parts: {missing_vars}. Run Parts 1-2 first.")

logger.info("Part 3: Portfolio & Recovery Analysis started")
print(f"\nAll required variables available. Starting Part 3: Portfolio & Recovery Analysis")

# %%
# ===================================================================
# SECTION 1: CORRELATION ANALYSIS
# ===================================================================

perf.start_timer('correlation_analysis')
logger.info("Starting portfolio correlation analysis...")


def get_strategy_returns_series(daily_data, strategy_names):
    """Extract aligned return series for each strategy."""
    data = daily_data.copy()

    # Normalize strategy column
    if 'strategy' not in data.columns:
        if 'strategy_id' in data.columns:
            data['strategy'] = data['strategy_id']
        elif 'strategy_index' in data.columns:
            data['strategy'] = 'Strategy_' + data['strategy_index'].astype(str)

    returns_dict = {}
    for strategy in strategy_names:
        sdata = data[data['strategy'] == strategy].sort_values('date')
        if len(sdata) < 30:
            continue

        returns = None
        for col in ['daily_roi', 'daily_return', 'roi', 'return', 'net_return']:
            if col in sdata.columns:
                returns = sdata[col]
                break
        if returns is None or returns.empty:
            if 'net_result' in sdata.columns and 'stake' in sdata.columns:
                returns = sdata['net_result'] / sdata['stake']
            else:
                continue
        if not returns.empty:
            returns_dict[strategy[:30]] = returns.values
    return returns_dict


def calculate_correlation_matrix(daily_data, strategy_names):
    """Calculate correlation matrix for strategy returns."""
    returns_dict = get_strategy_returns_series(daily_data, strategy_names)
    if len(returns_dict) < 2:
        return pd.DataFrame()

    min_length = min(len(r) for r in returns_dict.values())
    aligned = {k: v[-min_length:] for k, v in returns_dict.items()}
    return pd.DataFrame(aligned).corr()


def analyze_diversification(corr_matrix):
    """Analyze diversification metrics from correlation matrix."""
    if corr_matrix.empty:
        return {'error': 'Empty correlation matrix'}

    n = len(corr_matrix)
    upper = np.triu(corr_matrix.values, k=1)
    correlations = upper[upper != 0]

    equal_weights = np.ones(n) / n
    portfolio_var = np.dot(equal_weights, np.dot(corr_matrix.values, equal_weights))
    portfolio_vol = np.sqrt(portfolio_var)
    div_ratio = 1.0 / portfolio_vol if portfolio_vol > 0 else 1.0

    high_corr_pairs = []
    for i in range(n):
        for j in range(i + 1, n):
            c = corr_matrix.iloc[i, j]
            if abs(c) > 0.7:
                high_corr_pairs.append({
                    'strategy_1': corr_matrix.index[i],
                    'strategy_2': corr_matrix.index[j],
                    'correlation': c
                })

    return {
        'mean_correlation': float(np.mean(correlations)) if len(correlations) > 0 else 0,
        'std_correlation': float(np.std(correlations)) if len(correlations) > 0 else 0,
        'diversification_ratio': div_ratio,
        'high_correlation_pairs': high_corr_pairs,
        'effective_strategies': n,
    }


def calculate_optimal_weights(corr_matrix):
    """Calculate minimum variance portfolio weights."""
    if corr_matrix.empty:
        return {'error': 'Empty correlation matrix'}

    n = len(corr_matrix)
    equal_weights = np.ones(n) / n

    try:
        inv_cov = np.linalg.inv(corr_matrix.values)
        ones = np.ones((n, 1))
        weights = np.dot(inv_cov, ones) / np.dot(ones.T, np.dot(inv_cov, ones))
        weights = np.maximum(weights.flatten(), 0)
        weights = weights / np.sum(weights)

        equal_var = np.dot(equal_weights, np.dot(corr_matrix.values, equal_weights))
        opt_var = np.dot(weights, np.dot(corr_matrix.values, weights))
        risk_reduction = (equal_var - opt_var) / equal_var if equal_var > 0 else 0

        return {
            'optimal_weights': dict(zip(corr_matrix.index, weights)),
            'equal_weights': dict(zip(corr_matrix.index, equal_weights)),
            'risk_reduction_benefit': risk_reduction,
            'max_weight': float(np.max(weights)),
            'herfindahl_index': float(np.sum(weights ** 2))
        }
    except np.linalg.LinAlgError:
        return {
            'optimal_weights': dict(zip(corr_matrix.index, equal_weights)),
            'equal_weights': dict(zip(corr_matrix.index, equal_weights)),
            'error': 'Matrix inversion failed'
        }


def run_correlation_analysis(data, strategy_selection):
    """Complete correlation analysis pipeline."""
    if 'top_strategies_daily' not in data:
        logger.warning("Daily financial data not available for correlation analysis")
        return {'error': 'Daily financial data required'}

    if 'error' in strategy_selection or 'selected_strategies' not in strategy_selection:
        logger.warning("No strategies selected for correlation analysis")
        return {'error': 'No strategies selected'}

    daily_data = data['top_strategies_daily']
    strategy_names = strategy_selection['selected_strategies']['strategy'].tolist()

    logger.info(f"Calculating correlations for {len(strategy_names)} strategies...")
    corr_matrix = calculate_correlation_matrix(daily_data, strategy_names)

    if corr_matrix.empty:
        return {'error': 'Failed to calculate correlations'}

    logger.info(f"Correlation matrix: {corr_matrix.shape[0]}x{corr_matrix.shape[1]}")

    corr_analysis = analyze_diversification(corr_matrix)
    logger.info(f"Mean correlation: {corr_analysis.get('mean_correlation', 0):.3f}")
    logger.info(f"Diversification ratio: {corr_analysis.get('diversification_ratio', 0):.2f}")

    opt_weights = calculate_optimal_weights(corr_matrix)
    if 'risk_reduction_benefit' in opt_weights:
        logger.info(f"Risk reduction potential: {opt_weights['risk_reduction_benefit']:.1%}")

    # Recommendations
    recommendations = []
    div_ratio = corr_analysis.get('diversification_ratio', 1.0)
    if div_ratio < 1.2:
        recommendations.append({'type': 'warning', 'title': 'Limited Diversification',
                                'description': f'Ratio {div_ratio:.2f} suggests limited risk reduction'})
    elif div_ratio > 1.5:
        recommendations.append({'type': 'positive', 'title': 'Good Diversification',
                                'description': f'Ratio {div_ratio:.2f} indicates effective risk reduction'})

    high_corr = len(corr_analysis.get('high_correlation_pairs', []))
    if high_corr > 0:
        recommendations.append({'type': 'warning', 'title': 'High Correlations',
                                'description': f'{high_corr} pairs with correlation > 0.7'})

    print(f"Correlation analysis complete:")
    print(f"  Mean correlation: {corr_analysis.get('mean_correlation', 0):.3f}")
    print(f"  Diversification ratio: {corr_analysis.get('diversification_ratio', 0):.2f}")

    return {
        'correlation_matrix': corr_matrix,
        'correlation_analysis': corr_analysis,
        'optimal_weights': opt_weights,
        'diversification_recommendations': recommendations,
        'analysis_timestamp': datetime.now().isoformat()
    }


CORRELATION_RESULTS = run_correlation_analysis(DATA, STRATEGY_SELECTION)
perf.end_timer('correlation_analysis')

# %%
# ===================================================================
# SECTION 2: RECOVERY ANALYSIS
# ===================================================================

perf.start_timer('recovery_analysis')
logger.info("Starting recovery period analysis...")


def calculate_resilience_score(metrics):
    """Calculate resilience score (0-1) for a strategy."""
    score = 0.0

    # Recovery speed (30%)
    recovery_days = metrics.get('recovery_days', 999)
    if recovery_days < 30:
        score += 0.3
    elif recovery_days < 60:
        score += 0.2
    elif recovery_days < 90:
        score += 0.1

    # Recovery success (30%)
    if metrics.get('is_recovered', False):
        score += 0.3

    # Time underwater (20%)
    time_underwater = metrics.get('time_underwater_pct', 100)
    if time_underwater < 20:
        score += 0.2
    elif time_underwater < 40:
        score += 0.1

    # Drawdown magnitude (20%)
    max_dd = abs(metrics.get('max_drawdown_pct', 100))
    if max_dd < 10:
        score += 0.2
    elif max_dd < 20:
        score += 0.1

    return min(1.0, score)


def analyze_recovery_metrics(drawdown_results):
    """Analyze recovery metrics from drawdown results."""
    if 'individual_results' not in drawdown_results:
        logger.warning("Drawdown results not available for recovery analysis")
        return {'error': 'Drawdown results required'}

    recovery_summary = []
    for strategy_name, dd_results in drawdown_results['individual_results'].items():
        recovery_time = dd_results.get('recovery_duration_days')
        metrics = {
            'strategy': strategy_name,
            'max_drawdown_pct': dd_results.get('max_drawdown_pct', 0),
            'drawdown_days': dd_results.get('drawdown_duration_days', 0),
            'recovery_days': recovery_time if recovery_time is not None else 999,
            'is_recovered': dd_results.get('is_recovered', False),
            'time_underwater_pct': dd_results.get('time_underwater_pct', 0),
            'total_recovery_time': (dd_results.get('drawdown_duration_days', 0) +
                                    (recovery_time if recovery_time is not None else 0))
        }

        if recovery_time is not None and recovery_time > 0:
            metrics['recovery_efficiency'] = abs(dd_results.get('max_drawdown_pct', 1)) / recovery_time
        else:
            metrics['recovery_efficiency'] = 0

        metrics['resilience_score'] = calculate_resilience_score(metrics)
        recovery_summary.append(metrics)

    recovery_df = pd.DataFrame(recovery_summary)

    recovered = recovery_df[recovery_df['is_recovered']]
    portfolio_recovery = {
        'total_strategies': len(recovery_summary),
        'avg_recovery_time': float(recovered['recovery_days'].mean()) if len(recovered) > 0 else None,
        'median_recovery_time': float(recovered['recovery_days'].median()) if len(recovered) > 0 else None,
        'recovery_success_rate': float(recovery_df['is_recovered'].mean()),
        'avg_time_underwater': float(recovery_df['time_underwater_pct'].mean()),
        'avg_resilience_score': float(recovery_df['resilience_score'].mean()),
        'fastest_recovery_strategy': recovery_df.loc[recovery_df['recovery_days'].idxmin(), 'strategy'] if len(recovery_df) > 0 else None,
        'most_resilient_strategy': recovery_df.loc[recovery_df['resilience_score'].idxmax(), 'strategy'] if len(recovery_df) > 0 else None
    }

    logger.info(f"Recovery analysis: {portfolio_recovery['total_strategies']} strategies")
    logger.info(f"  Recovery success rate: {portfolio_recovery['recovery_success_rate']:.1%}")
    logger.info(f"  Avg resilience score: {portfolio_recovery['avg_resilience_score']:.2f}")

    print(f"Recovery analysis complete:")
    print(f"  Strategies analyzed: {portfolio_recovery['total_strategies']}")
    if portfolio_recovery['avg_recovery_time'] is not None:
        print(f"  Average recovery time: {portfolio_recovery['avg_recovery_time']:.1f} days")
    print(f"  Recovery success rate: {portfolio_recovery['recovery_success_rate']:.1%}")
    print(f"  Average resilience score: {portfolio_recovery['avg_resilience_score']:.2f}")

    return {
        'recovery_summary': recovery_df,
        'portfolio_recovery': portfolio_recovery,
        'analysis_timestamp': datetime.now().isoformat()
    }


RECOVERY_RESULTS = analyze_recovery_metrics(DRAWDOWN_RESULTS)
perf.end_timer('recovery_analysis')

# %%
# ===================================================================
# SECTION 3: INTEGRATED PORTFOLIO INSIGHTS
# ===================================================================

perf.start_timer('portfolio_insights')
logger.info("Generating integrated portfolio insights...")


def extract_portfolio_metrics(all_results):
    """Extract key metrics from all analyses."""
    metrics = {
        'portfolio_characteristics': {},
        'risk_profile': {},
        'performance_metrics': {}
    }

    if 'correlation_results' in all_results:
        corr = all_results['correlation_results'].get('correlation_analysis', {})
        metrics['portfolio_characteristics']['diversification_ratio'] = corr.get('diversification_ratio', 1.0)
        metrics['portfolio_characteristics']['mean_correlation'] = corr.get('mean_correlation', 0)

    if 'drawdown_results' in all_results:
        dd = all_results['drawdown_results'].get('portfolio_summary', {})
        metrics['risk_profile']['avg_max_drawdown'] = dd.get('avg_max_drawdown', 0)
        metrics['risk_profile']['worst_drawdown'] = dd.get('worst_drawdown', 0)

    if 'var_results' in all_results:
        var = all_results['var_results'].get('summary_statistics', {})
        metrics['risk_profile']['avg_var_95'] = var.get('avg_var_95', 0)
        metrics['risk_profile']['worst_var_95'] = var.get('worst_var_95', 0)

    if 'performance_results' in all_results:
        p = all_results['performance_results'].get('portfolio_summary', {})
        metrics['performance_metrics']['avg_sharpe_ratio'] = p.get('avg_sharpe_ratio', 0)
        metrics['performance_metrics']['avg_annual_return'] = p.get('avg_annual_return', 0)

    if 'recovery_results' in all_results:
        rec = all_results['recovery_results'].get('portfolio_recovery', {})
        metrics['risk_profile']['avg_recovery_time'] = rec.get('avg_recovery_time', 0)
        metrics['risk_profile']['recovery_success_rate'] = rec.get('recovery_success_rate', 0)

    return metrics


def calculate_portfolio_score(metrics):
    """Calculate overall portfolio quality score (0-100)."""
    score = 0.0

    # Diversification (25 points)
    div_ratio = metrics['portfolio_characteristics'].get('diversification_ratio', 1.0)
    score += min(25, (div_ratio - 1.0) * 50)

    # Performance (25 points)
    sharpe = metrics['performance_metrics'].get('avg_sharpe_ratio', 0)
    score += min(25, max(0, sharpe * 12.5))

    # Risk control (25 points)
    max_dd = abs(metrics['risk_profile'].get('worst_drawdown', 50))
    score += min(25, max(0, 25 - max_dd * 0.5))

    # Recovery (25 points)
    recovery_rate = metrics['risk_profile'].get('recovery_success_rate', 0)
    score += recovery_rate * 25

    return max(0, min(100, score))


def generate_strategic_recommendations(metrics, portfolio_score):
    """Generate strategic recommendations based on metrics."""
    recommendations = []

    if portfolio_score < 60:
        recommendations.append({
            'category': 'Portfolio Optimization', 'priority': 'High',
            'recommendation': 'Comprehensive portfolio restructuring needed',
            'rationale': f'Portfolio score of {portfolio_score:.1f}/100 below target'
        })

    div_ratio = metrics['portfolio_characteristics'].get('diversification_ratio', 1.0)
    if div_ratio < 1.3:
        recommendations.append({
            'category': 'Diversification', 'priority': 'Medium',
            'recommendation': 'Increase portfolio diversification',
            'rationale': f'Diversification ratio of {div_ratio:.2f} is suboptimal'
        })

    max_dd = abs(metrics['risk_profile'].get('worst_drawdown', 0))
    if max_dd > 25:
        recommendations.append({
            'category': 'Risk Management', 'priority': 'High',
            'recommendation': 'Implement enhanced risk controls',
            'rationale': f'Maximum drawdown of {max_dd:.1f}% exceeds risk limits'
        })

    sharpe = metrics['performance_metrics'].get('avg_sharpe_ratio', 0)
    if sharpe < 1.0:
        recommendations.append({
            'category': 'Performance', 'priority': 'Medium',
            'recommendation': 'Focus on improving risk-adjusted returns',
            'rationale': f'Sharpe ratio of {sharpe:.2f} below target of 1.0'
        })

    return recommendations


def identify_opportunities(metrics):
    """Identify optimization opportunities."""
    opportunities = []

    div_ratio = metrics['portfolio_characteristics'].get('diversification_ratio', 1.0)
    if div_ratio < 1.5:
        opportunities.append({
            'area': 'Diversification', 'opportunity': 'Add uncorrelated strategies',
            'potential_improvement': '15-25% risk reduction'
        })

    recovery_time = metrics['risk_profile'].get('avg_recovery_time', 0)
    if recovery_time and recovery_time > 45:
        opportunities.append({
            'area': 'Recovery', 'opportunity': 'Improve recovery characteristics',
            'potential_improvement': 'Faster drawdown recovery'
        })

    return opportunities


def get_risk_level(metrics):
    max_dd = abs(metrics['risk_profile'].get('worst_drawdown', 0))
    var_95 = abs(metrics['risk_profile'].get('avg_var_95', 0))
    if max_dd < 15 and var_95 < 0.05:
        return "Low Risk"
    elif max_dd < 25 and var_95 < 0.10:
        return "Medium Risk"
    return "High Risk"


def get_diversification_rating(metrics):
    div_ratio = metrics['portfolio_characteristics'].get('diversification_ratio', 1.0)
    if div_ratio >= 1.5:
        return "Excellent"
    elif div_ratio >= 1.3:
        return "Good"
    elif div_ratio >= 1.1:
        return "Fair"
    return "Poor"


def get_recovery_rating(metrics):
    rate = metrics['risk_profile'].get('recovery_success_rate', 0)
    if rate >= 0.8:
        return "Strong"
    elif rate >= 0.6:
        return "Moderate"
    return "Weak"


def generate_portfolio_insights(all_results):
    """Generate comprehensive portfolio insights."""
    metrics = extract_portfolio_metrics(all_results)
    score = calculate_portfolio_score(metrics)
    metrics['portfolio_score'] = score
    metrics['strategic_recommendations'] = generate_strategic_recommendations(metrics, score)
    metrics['optimization_opportunities'] = identify_opportunities(metrics)

    logger.info(f"Portfolio score: {score:.1f}/100")
    logger.info(f"Risk level: {get_risk_level(metrics)}")
    logger.info(f"Diversification: {get_diversification_rating(metrics)}")

    print(f"Portfolio assessment:")
    print(f"  Portfolio Score: {score:.1f}/100")
    print(f"  Risk Level: {get_risk_level(metrics)}")
    print(f"  Diversification: {get_diversification_rating(metrics)}")
    print(f"  Recovery Capability: {get_recovery_rating(metrics)}")
    print(f"  Recommendations: {len(metrics['strategic_recommendations'])}")

    return metrics


ALL_RESULTS = {
    'drawdown_results': DRAWDOWN_RESULTS,
    'var_results': VAR_RESULTS,
    'performance_results': PERFORMANCE_RESULTS,
    'correlation_results': CORRELATION_RESULTS,
    'recovery_results': RECOVERY_RESULTS
}

INTEGRATED_INSIGHTS = generate_portfolio_insights(ALL_RESULTS)
perf.end_timer('portfolio_insights')

# %%
# ===================================================================
# 📋 PART 3 COMPLETION SUMMARY
# ===================================================================

print(f"\n" + "=" * 80)
print("📋 PART 3: PORTFOLIO & RECOVERY ANALYSIS - COMPLETION SUMMARY")
print("=" * 80)

# Correlation Analysis Summary
if 'correlation_analysis' in CORRELATION_RESULTS:
    corr_analysis = CORRELATION_RESULTS['correlation_analysis']
    print(f"✅ Portfolio Correlation Analysis:")
    print(f"   - Diversification ratio: {corr_analysis.get('diversification_ratio', 0):.2f}")
    print(f"   - Mean correlation: {corr_analysis.get('mean_correlation', 0):+.3f}")
    
    if 'optimal_weights' in CORRELATION_RESULTS:
        risk_reduction = CORRELATION_RESULTS['optimal_weights'].get('risk_reduction_benefit', 0)
        print(f"   - Risk reduction potential: {risk_reduction:.1%}")

# Recovery Analysis Summary
if 'portfolio_recovery' in RECOVERY_RESULTS:
    portfolio_recovery = RECOVERY_RESULTS['portfolio_recovery']
    print(f"✅ Recovery Period Analysis:")
    if portfolio_recovery.get('avg_recovery_time') is not None:
        print(f"   - Average recovery time: {portfolio_recovery['avg_recovery_time']:.1f} days")
    print(f"   - Recovery success rate: {portfolio_recovery.get('recovery_success_rate', 0):.1%}")
    print(f"   - Average resilience score: {portfolio_recovery.get('avg_resilience_score', 0):.2f}")

# Integrated Insights Summary
if 'portfolio_score' in INTEGRATED_INSIGHTS:
    portfolio_score = INTEGRATED_INSIGHTS['portfolio_score']
    strategic_recs = len(INTEGRATED_INSIGHTS.get('strategic_recommendations', []))
    optimization_opps = len(INTEGRATED_INSIGHTS.get('optimization_opportunities', []))
    
    print(f"✅ Integrated Portfolio Analysis:")
    print(f"   - Portfolio quality score: {portfolio_score:.1f}/100")
    print(f"   - Strategic recommendations: {strategic_recs}")
    print(f"   - Optimization opportunities: {optimization_opps}")

print(f"\n💾 Session data available:")
print(f"   - CORRELATION_RESULTS: Strategy correlation and diversification")
print(f"   - RECOVERY_RESULTS: Recovery period analysis")
print(f"   - INTEGRATED_INSIGHTS: Combined portfolio insights")

print(f"\n🎯 Ready to proceed to Part 4: Summary & Export")
print("=" * 80)

# %% [markdown]
# ---
#
# # 📤 PART 4: SUMMARY & EXPORT
#
# **Executive summary, professional visualizations, and comprehensive reporting**
#
# ---

# %%
# ===================================================================
# RISK ASSESSMENT - PART 4: SUMMARY & EXPORT
# ===================================================================

# Verify all previous parts data availability
required_vars = [
    'DATA', 'STRATEGY_SELECTION', 'DRAWDOWN_RESULTS',
    'VAR_RESULTS', 'PERFORMANCE_RESULTS', 'CORRELATION_RESULTS',
    'RECOVERY_RESULTS', 'INTEGRATED_INSIGHTS'
]
missing_vars = [v for v in required_vars if v not in globals()]

print("Checking required variables from previous parts...")
for var in required_vars:
    status = "available" if var in globals() else "MISSING"
    print(f"  {var}: {status}")

if missing_vars:
    raise RuntimeError(f"Missing data from previous parts: {missing_vars}. Run Parts 1-3 first.")

logger.info("Part 4: Summary & Export started")
print(f"\nAll {len(required_vars)} required variables available. Starting Part 4: Summary & Export")

# %%
# ===================================================================
# SECTION 1: EXECUTIVE SUMMARY GENERATOR
# ===================================================================

perf.start_timer('executive_summary')
logger.info("Generating executive risk assessment summary...")


def create_portfolio_overview(all_data):
    """Create portfolio overview section."""
    strategy_selection = all_data.get('strategy_selection', {})
    return {
        'total_strategies_analyzed': len(strategy_selection.get('selected_strategies', [])),
        'total_historical_bets': strategy_selection.get('summary', {}).get('total_bets', 0),
        'portfolio_avg_roi': strategy_selection.get('summary', {}).get('avg_roi', 0),
    }


def assess_risk_profile(all_data):
    """Assess overall risk profile."""
    dd_summary = all_data.get('drawdown_results', {}).get('portfolio_summary', {})
    var_summary = all_data.get('var_results', {}).get('summary_statistics', {})

    max_dd = abs(dd_summary.get('worst_drawdown', 0))
    avg_var = abs(var_summary.get('avg_var_95', 0))

    if max_dd < 15 and avg_var < 0.05:
        risk_level, risk_score = 'Low Risk', 1.0
    elif max_dd < 25 and avg_var < 0.10:
        risk_level, risk_score = 'Medium Risk', 2.0
    else:
        risk_level, risk_score = 'High Risk', 3.0

    return {
        'overall_risk_level': risk_level,
        'risk_score': risk_score,
        'max_drawdown': max_dd,
        'avg_var_95': avg_var * 100,
        'risk_factors': {
            'drawdown_risk': 'High' if max_dd > 25 else 'Medium' if max_dd > 15 else 'Low',
            'var_risk': 'High' if avg_var > 0.10 else 'Medium' if avg_var > 0.05 else 'Low'
        }
    }


def identify_strengths(all_data):
    """Identify portfolio strengths."""
    strengths = []

    div_ratio = all_data.get('correlation_results', {}).get('correlation_analysis', {}).get('diversification_ratio', 1.0)
    if div_ratio > 1.4:
        strengths.append(f"Strong diversification (ratio: {div_ratio:.2f})")

    avg_sharpe = all_data.get('performance_results', {}).get('portfolio_summary', {}).get('avg_sharpe_ratio', 0)
    if avg_sharpe > 1.2:
        strengths.append(f"Excellent risk-adjusted returns (Sharpe: {avg_sharpe:.2f})")

    recovery_rate = all_data.get('recovery_results', {}).get('portfolio_recovery', {}).get('recovery_success_rate', 0)
    if recovery_rate > 0.8:
        strengths.append(f"Strong recovery capability ({recovery_rate:.1%} success rate)")

    if not strengths:
        strengths.append("Portfolio meets basic risk management standards")
    return strengths


def identify_concerns(all_data):
    """Identify portfolio concerns."""
    concerns = []

    max_dd = abs(all_data.get('drawdown_results', {}).get('portfolio_summary', {}).get('worst_drawdown', 0))
    if max_dd > 25:
        concerns.append(f"High maximum drawdown risk ({max_dd:.1f}%)")

    div_ratio = all_data.get('correlation_results', {}).get('correlation_analysis', {}).get('diversification_ratio', 1.0)
    if div_ratio < 1.2:
        concerns.append(f"Limited diversification benefits (ratio: {div_ratio:.2f})")

    worst_var = abs(all_data.get('var_results', {}).get('summary_statistics', {}).get('worst_var_95', 0))
    if worst_var > 0.15:
        concerns.append(f"High worst-case loss potential (VaR 95%: {worst_var:.1%})")

    return concerns


def create_strategic_assessment(all_data):
    """Create strategic assessment."""
    portfolio_score = all_data.get('integrated_insights', {}).get('portfolio_score', 50)

    if portfolio_score >= 80:
        quality_rating = 'Excellent'
    elif portfolio_score >= 65:
        quality_rating = 'Good'
    elif portfolio_score >= 50:
        quality_rating = 'Fair'
    else:
        quality_rating = 'Poor'

    return {
        'portfolio_quality_rating': quality_rating,
        'portfolio_score': portfolio_score,
        'key_strengths': identify_strengths(all_data),
        'key_concerns': identify_concerns(all_data)
    }


def generate_bottom_line(risk_assessment, strategic_assessment):
    """Generate bottom-line go/no-go assessment."""
    score = strategic_assessment['portfolio_score']
    risk_level = risk_assessment['overall_risk_level']

    if score >= 75 and risk_level != 'High Risk':
        decision, rationale = 'GO', 'Portfolio meets all key performance and risk criteria'
        action = 'Proceed with current strategy allocation'
    elif score >= 60:
        decision, rationale = 'CONDITIONAL GO', 'Portfolio shows promise but requires optimization'
        action = 'Implement recommended improvements before scaling'
    else:
        decision, rationale = 'NO GO', 'Portfolio does not meet minimum standards'
        action = 'Substantial restructuring required'

    return {'go_no_go_decision': decision, 'decision_rationale': rationale, 'key_action_required': action}


def generate_executive_recommendations(risk_assessment, strategic_assessment):
    """Generate executive-level recommendations."""
    recommendations = []

    if risk_assessment['risk_score'] >= 2.5:
        recommendations.append({
            'category': 'Risk Management', 'priority': 'High',
            'recommendation': 'Implement enhanced risk controls',
            'expected_outcome': 'Reduced portfolio volatility and drawdown risk'
        })

    if strategic_assessment['portfolio_score'] < 70:
        recommendations.append({
            'category': 'Portfolio Optimization', 'priority': 'High',
            'recommendation': 'Restructure portfolio for improved performance',
            'expected_outcome': 'Enhanced risk-adjusted returns'
        })

    return recommendations


def generate_executive_summary(all_data):
    """Generate comprehensive executive summary."""
    portfolio_overview = create_portfolio_overview(all_data)
    risk_assess = assess_risk_profile(all_data)
    strategic_assess = create_strategic_assessment(all_data)
    bottom_line = generate_bottom_line(risk_assess, strategic_assess)

    summary = {
        'analysis_metadata': {
            'analysis_date': datetime.now().isoformat(),
            'analysis_scope': 'Comprehensive Hockey Betting Strategy Risk Assessment',
            'confidence_level': '95% statistical confidence'
        },
        'portfolio_overview': portfolio_overview,
        'risk_assessment': risk_assess,
        'strategic_assessment': strategic_assess,
        'bottom_line_assessment': bottom_line,
        'executive_recommendations': generate_executive_recommendations(risk_assess, strategic_assess)
    }

    # Display
    overview = summary['portfolio_overview']
    risk = summary['risk_assessment']
    bl = summary['bottom_line_assessment']

    logger.info(f"Executive summary: {bl['go_no_go_decision']}")
    logger.info(f"Risk level: {risk['overall_risk_level']}, Max DD: {risk['max_drawdown']:.1f}%")

    print(f"\nExecutive Risk Assessment Summary")
    print("=" * 60)
    print(f"Portfolio Overview:")
    print(f"  Strategies Analyzed: {overview['total_strategies_analyzed']}")
    print(f"  Historical Bets: {overview['total_historical_bets']:,}")
    print(f"  Average ROI: {overview['portfolio_avg_roi']:+.1%}")
    print(f"Risk Assessment:")
    print(f"  Overall Risk Level: {risk['overall_risk_level']} (Score: {risk['risk_score']:.1f}/3.0)")
    print(f"  Max Drawdown: {risk['max_drawdown']:.1f}%")
    print(f"  VaR 95%: {risk['avg_var_95']:.1f}%")
    print(f"Bottom Line:")
    print(f"  Decision: {bl['go_no_go_decision']}")
    print(f"  Rationale: {bl['decision_rationale']}")
    print(f"  Key Action: {bl['key_action_required']}")

    return summary


ALL_DATA = {
    'data': DATA,
    'strategy_selection': STRATEGY_SELECTION,
    'drawdown_results': DRAWDOWN_RESULTS,
    'var_results': VAR_RESULTS,
    'performance_results': PERFORMANCE_RESULTS,
    'correlation_results': CORRELATION_RESULTS,
    'recovery_results': RECOVERY_RESULTS,
    'integrated_insights': INTEGRATED_INSIGHTS
}

EXECUTIVE_SUMMARY = generate_executive_summary(ALL_DATA)
perf.end_timer('executive_summary')

# %%
# ===================================================================
# SECTION 2: VISUALIZATION CREATOR
# ===================================================================

perf.start_timer('visualizations')
logger.info("Creating risk visualizations...")

CHARTS_EXPORT_DIR.mkdir(parents=True, exist_ok=True)


def create_drawdown_chart(all_data, export_dir):
    """Create drawdown analysis chart."""
    dd_results = all_data.get('drawdown_results', {})
    if 'summary_statistics' not in dd_results:
        return None

    summary_df = dd_results['summary_statistics']
    fig = make_subplots(rows=1, cols=2,
                        subplot_titles=['Maximum Drawdown by Strategy', 'Recovery Time Analysis'])

    fig.add_trace(go.Bar(
        x=summary_df['strategy'].str[:15], y=summary_df['max_drawdown_pct'],
        name='Max Drawdown (%)', marker_color='rgba(255, 99, 132, 0.8)'
    ), row=1, col=1)

    fig.add_trace(go.Bar(
        x=summary_df['strategy'].str[:15], y=summary_df['recovery_duration_days'],
        name='Recovery Time (days)', marker_color='rgba(54, 162, 235, 0.8)'
    ), row=1, col=2)

    fig.update_layout(height=500, title_text="Drawdown Risk Analysis", showlegend=False)

    filename = "risk_assessment_drawdown_analysis.html"
    fig.write_html(str(export_dir / filename))
    return filename


def create_var_chart(all_data, export_dir):
    """Create VaR analysis chart."""
    var_results = all_data.get('var_results', {})
    if 'individual_results' not in var_results:
        return None

    strategies, var_95, var_99 = [], [], []
    for strategy, results in var_results['individual_results'].items():
        strategies.append(strategy[:15])
        var_95.append(abs(results['monte_carlo_var']['95%']) * 100)
        var_99.append(abs(results['monte_carlo_var']['99%']) * 100)

    fig = go.Figure()
    fig.add_trace(go.Bar(name='VaR 95%', x=strategies, y=var_95,
                         marker_color='rgba(255, 206, 86, 0.8)'))
    fig.add_trace(go.Bar(name='VaR 99%', x=strategies, y=var_99,
                         marker_color='rgba(255, 99, 132, 0.8)'))
    fig.update_layout(title='Value at Risk Analysis', xaxis_title='Strategy',
                      yaxis_title='VaR (%)', barmode='group', height=500)

    filename = "risk_assessment_var_analysis.html"
    fig.write_html(str(export_dir / filename))
    return filename


def create_risk_return_chart(all_data, export_dir):
    """Create risk-return scatter plot."""
    perf_results = all_data.get('performance_results', {})
    if 'summary_statistics' not in perf_results:
        return None

    summary_df = perf_results['summary_statistics']
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=summary_df['annual_volatility'] * 100,
        y=summary_df['annual_return'] * 100,
        mode='markers+text',
        text=summary_df['strategy_name'].str[:10],
        textposition='top center',
        marker=dict(size=summary_df['sharpe_ratio'] * 10,
                    color=summary_df['sharpe_ratio'],
                    colorscale='Viridis', showscale=True,
                    colorbar=dict(title="Sharpe Ratio"))
    ))
    fig.update_layout(title='Risk-Return Profile', xaxis_title='Annual Volatility (%)',
                      yaxis_title='Annual Return (%)', height=600)
    fig.add_hline(y=0, line_dash="dot", line_color="gray")

    filename = "risk_assessment_risk_return.html"
    fig.write_html(str(export_dir / filename))
    return filename


def create_correlation_heatmap(all_data, export_dir):
    """Create correlation heatmap."""
    corr_results = all_data.get('correlation_results', {})
    if 'correlation_matrix' not in corr_results:
        return None

    corr_matrix = corr_results['correlation_matrix']
    fig = go.Figure(data=go.Heatmap(
        z=corr_matrix.values, x=corr_matrix.columns, y=corr_matrix.index,
        colorscale='RdBu', zmid=0,
        text=corr_matrix.round(2).values, texttemplate="%{text}", textfont={"size": 10}
    ))
    fig.update_layout(title='Strategy Correlation Matrix', height=600)

    filename = "risk_assessment_correlations.html"
    fig.write_html(str(export_dir / filename))
    return filename


def create_portfolio_dashboard(all_data, export_dir):
    """Create comprehensive portfolio dashboard."""
    insights = all_data.get('integrated_insights', {})
    executive_summary = all_data.get('executive_summary', EXECUTIVE_SUMMARY)

    fig = make_subplots(
        rows=2, cols=2,
        subplot_titles=['Portfolio Score', 'Risk Metrics', 'Performance Metrics', 'Key Recommendations'],
        specs=[[{"type": "indicator"}, {"type": "bar"}],
               [{"type": "scatter"}, {"type": "table"}]]
    )

    portfolio_score = insights.get('portfolio_score', 50)
    fig.add_trace(go.Indicator(
        mode="gauge+number", value=portfolio_score,
        title={'text': "Portfolio Quality Score"},
        gauge={'axis': {'range': [None, 100]},
               'bar': {'color': "green" if portfolio_score > 70 else "orange" if portfolio_score > 50 else "red"},
               'steps': [{'range': [0, 50], 'color': "lightgray"},
                         {'range': [50, 70], 'color': "yellow"},
                         {'range': [70, 100], 'color': "lightgreen"}]}
    ), row=1, col=1)

    risk_data = executive_summary.get('risk_assessment', {})
    fig.add_trace(go.Bar(
        x=['Max Drawdown', 'VaR 95%'],
        y=[risk_data.get('max_drawdown', 0), risk_data.get('avg_var_95', 0)],
        marker_color=['red', 'orange']
    ), row=1, col=2)

    fig.update_layout(height=800, title_text="Risk Assessment Dashboard", showlegend=False)

    filename = "risk_assessment_dashboard.html"
    fig.write_html(str(export_dir / filename))
    return filename


def create_all_visualizations(all_data, export_dir):
    """Create all risk assessment visualizations."""
    if not PLOTLY_AVAILABLE:
        logger.warning("Plotly not available, skipping interactive visualizations")
        print("Plotly not available, skipping interactive visualizations")
        return []

    created_files = []
    visualizations = [
        ('drawdown_analysis', create_drawdown_chart),
        ('var_analysis', create_var_chart),
        ('risk_return_scatter', create_risk_return_chart),
        ('correlation_heatmap', create_correlation_heatmap),
        ('portfolio_dashboard', create_portfolio_dashboard),
    ]

    for viz_name, viz_func in visualizations:
        try:
            filename = viz_func(all_data, export_dir)
            if filename:
                created_files.append(filename)
                logger.info(f"Created visualization: {filename}")
                print(f"  Created: {filename}")
        except Exception as e:
            logger.error(f"Error creating {viz_name}: {e}")
            print(f"  Error creating {viz_name}: {e}")

    print(f"Created {len(created_files)} visualizations in {export_dir}")
    return created_files


VISUALIZATION_EXPORTS = create_all_visualizations(ALL_DATA, CHARTS_EXPORT_DIR)
perf.end_timer('visualizations')

# %%
# ===================================================================
# SECTION 3: REPORT EXPORTER
# ===================================================================

perf.start_timer('report_export')
logger.info("Exporting risk assessment reports...")

RESULTS_DIR.mkdir(parents=True, exist_ok=True)


def export_executive_json(executive_summary, export_dir, timestamp):
    """Export executive summary as JSON using safe file handler."""
    try:
        filename = f"risk_assessment_executive_{timestamp}.json"
        filepath = export_dir / filename
        write_json(executive_summary, filepath)
        logger.info(f"Executive summary JSON: {filename}")
        print(f"  Executive summary JSON: {filename}")
        return filename
    except Exception as e:
        logger.error(f"Error exporting JSON: {e}")
        print(f"  Error exporting JSON: {e}")
        return None


def export_strategy_metrics_csv(all_results, export_dir, timestamp):
    """Export strategy metrics as CSV."""
    try:
        perf_df = all_results.get('performance_results', {}).get('summary_statistics', pd.DataFrame())
        if isinstance(perf_df, pd.DataFrame) and perf_df.empty:
            return None

        filename = f"risk_assessment_metrics_{timestamp}.csv"
        filepath = export_dir / filename
        perf_df.to_csv(filepath, index=False, encoding='utf-8')
        logger.info(f"Strategy metrics CSV: {filename}")
        print(f"  Strategy metrics CSV: {filename}")
        return filename
    except Exception as e:
        logger.error(f"Error exporting CSV: {e}")
        print(f"  Error exporting CSV: {e}")
        return None


def generate_html_report(executive_summary):
    """Generate HTML report content."""
    overview = executive_summary.get('portfolio_overview', {})
    risk = executive_summary.get('risk_assessment', {})
    bottom_line = executive_summary.get('bottom_line_assessment', {})
    decision_class = bottom_line.get('go_no_go_decision', '').lower().replace(' ', '-')

    return f"""<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8">
    <title>Risk Assessment Report</title>
    <style>
        body {{ font-family: Arial, sans-serif; margin: 40px; }}
        .header {{ background: #2c3e50; color: white; padding: 20px; text-align: center; }}
        .section {{ margin: 20px 0; padding: 20px; background: #f8f9fa; border-radius: 8px; }}
        .metric {{ display: inline-block; margin: 10px; padding: 10px; background: white; border-radius: 5px; }}
        .go {{ background: #d4edda; color: #155724; padding: 20px; border-radius: 8px; }}
        .conditional-go {{ background: #fff3cd; color: #856404; padding: 20px; border-radius: 8px; }}
        .no-go {{ background: #f8d7da; color: #721c24; padding: 20px; border-radius: 8px; }}
    </style>
</head>
<body>
    <div class="header">
        <h1>Hockey Betting Strategy Risk Assessment</h1>
        <p>Generated: {datetime.now().strftime('%Y-%m-%d %H:%M')}</p>
    </div>
    <div class="section">
        <h2>Portfolio Overview</h2>
        <div class="metric">Strategies: {overview.get('total_strategies_analyzed', 0)}</div>
        <div class="metric">Total Bets: {overview.get('total_historical_bets', 0):,}</div>
        <div class="metric">Avg ROI: {overview.get('portfolio_avg_roi', 0):+.1%}</div>
    </div>
    <div class="section">
        <h2>Risk Assessment</h2>
        <p>Risk Level: {risk.get('overall_risk_level', 'Unknown')}</p>
        <p>Max Drawdown: {risk.get('max_drawdown', 0):.1f}%</p>
        <p>VaR 95%: {risk.get('avg_var_95', 0):.1f}%</p>
    </div>
    <div class="{decision_class}">
        <h2>Decision: {bottom_line.get('go_no_go_decision', 'Unknown')}</h2>
        <p>{bottom_line.get('decision_rationale', '')}</p>
        <p><strong>Action Required:</strong> {bottom_line.get('key_action_required', '')}</p>
    </div>
</body>
</html>"""


def export_html_report(executive_summary, export_dir, timestamp):
    """Export HTML executive report."""
    try:
        filename = f"risk_assessment_report_{timestamp}.html"
        filepath = export_dir / filename
        html_content = generate_html_report(executive_summary)
        filepath.write_text(html_content, encoding='utf-8')
        logger.info(f"HTML report: {filename}")
        print(f"  HTML report: {filename}")
        return filename
    except Exception as e:
        logger.error(f"Error exporting HTML: {e}")
        print(f"  Error exporting HTML: {e}")
        return None


def export_all_reports(executive_summary, all_results, export_dir):
    """Export all report formats."""
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    exported_files = {}

    exec_file = export_executive_json(executive_summary, export_dir, timestamp)
    if exec_file:
        exported_files['executive_summary'] = exec_file

    metrics_file = export_strategy_metrics_csv(all_results, export_dir, timestamp)
    if metrics_file:
        exported_files['strategy_metrics'] = metrics_file

    html_file = export_html_report(executive_summary, export_dir, timestamp)
    if html_file:
        exported_files['html_report'] = html_file

    logger.info(f"Exported {len(exported_files)} reports to {export_dir}")
    print(f"Exported {len(exported_files)} reports")
    return exported_files


REPORT_EXPORTS = export_all_reports(EXECUTIVE_SUMMARY, ALL_RESULTS, RESULTS_DIR)
perf.end_timer('report_export')

# %%
# ===================================================================
# FINAL COMPLETION SUMMARY
# ===================================================================

perf.end_timer('total_analysis') if 'total_analysis' in perf._timers else None

print("=" * 80)
print("RISK ASSESSMENT ANALYSIS - COMPLETE")
print("=" * 80)

print(f"\nAnalysis Summary:")
print(f"  Part 1: Data Pipeline - {len(DATA)} datasets loaded")
print(f"  Part 2: Core Risk Analysis - {len(DRAWDOWN_RESULTS.get('individual_results', {}))} strategies analyzed")
print(f"  Part 3: Portfolio Analysis - Diversification ratio: {CORRELATION_RESULTS.get('correlation_analysis', {}).get('diversification_ratio', 0):.2f}")
print(f"  Part 4: Summary & Export - {len(VISUALIZATION_EXPORTS)} visualizations, {len(REPORT_EXPORTS)} reports")

# Key Results
print(f"\nKey Results:")
if 'portfolio_score' in INTEGRATED_INSIGHTS:
    print(f"  Portfolio Score: {INTEGRATED_INSIGHTS['portfolio_score']:.1f}/100")

if 'bottom_line_assessment' in EXECUTIVE_SUMMARY:
    bl = EXECUTIVE_SUMMARY['bottom_line_assessment']
    print(f"  Go/No-Go Decision: {bl.get('go_no_go_decision', 'Unknown')}")

if 'risk_assessment' in EXECUTIVE_SUMMARY:
    risk = EXECUTIVE_SUMMARY['risk_assessment']
    print(f"  Risk Level: {risk.get('overall_risk_level', 'Unknown')}")
    print(f"  Max Drawdown: {risk.get('max_drawdown', 0):.1f}%")

print(f"\nExported Files:")
print(f"  Visualizations ({len(VISUALIZATION_EXPORTS)}):")
for viz_file in VISUALIZATION_EXPORTS:
    print(f"    - {viz_file}")

print(f"  Reports ({len(REPORT_EXPORTS)}):")
for report_type, report_file in REPORT_EXPORTS.items():
    print(f"    - {report_type}: {report_file}")

logger.info("Risk Assessment Analysis completed successfully")
logger.info(f"Total visualizations: {len(VISUALIZATION_EXPORTS)}, reports: {len(REPORT_EXPORTS)}")
print("\nRisk Assessment Complete!")
print("=" * 80)
